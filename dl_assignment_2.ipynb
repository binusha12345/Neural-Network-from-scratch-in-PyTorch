# %% [markdown]
# # Assignment 2: Neural Network in Pytorch

# %% [markdown]
# ## Section 1 Background and Instructions

# %% [markdown]
# ## Background
#
# Neural Networks are a class of algorithms, loosely modeled after human biological neural networks in the brain. They are instrumental in extracting patterns out of the dataset provided. Most of the present day advancements in Artificial Intelligence are made possible by the different variants of neural networks.

# %% [markdown]
# ## Assignment
# In this assignment, we will develop a Neural Network and write the entire training loop of that Neural Network using a library called Pytorch. Pytorch, released by Meta (also known as Facebook) is perhaps today the most popular package used to develop a neural network. We are going to implement the backpropagation algorithm in Pytorch. Backpropagation was first postulated roughly 40 years ago by Geoffrey Hinton - one of the authority figures in Deep Learning today. He was awarded the Turing Prize for his contributions.

# %% [markdown]
# ## Instructions
#
# Complete the starter code methods provided without changing their signatures or return values.
#
# ### Note:
# You are expected to write code where you see **your code here**.
# Make sure you delete the lines with **raise NotImplementedError** or your code may not run correctly.

# %% [markdown]
# ## Import Libraries
#
# The code cell below contains the basic python packages you will need to complete this assignment. Do not update
# the python package or add new ones. Doing so will may cause the autograder to fail.

# %%
#Basic libraries for functionalities
import numpy as np              #numpy library stands for numerical python - they create a datatype called arrays which speeds up calculation
import matplotlib.pyplot as plt #matplotlib is a library used for drawing graphs and plotting
import random                   #used to create random datasets

# %% [markdown]
# ## About Pytorch
# Building a Deep Learning model is a customizable process; for example, someone may want to build a Deep Learning model to extract large features from an image, whereas someone else may only want to extract small features from it. In order to address this, packages were developed for creating Deep Learning models, such as tensorflow, keras and Pytorch. Pytorch is the perhaps the package most widely used by developers. This framework provides Deep Learning model building blocks that developers can assemble for their needs.
#
# ## PyTorch Blitz
# Here is a quick introduction to PyTorch(60 minutes) provided by the developers of PyTorch itself. Please watch it if you are new to PyTorch.
# https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html

# %%
#More libraries for implementing our neural network
import torch                                        #pytorch library 
from torch.utils.data import DataLoader, Dataset    #importing the dataset and dotaloader class which we will use to input the data
import torch.optim as optim                         #optimizer for pytorch
import torch.nn as nn                               #neural network module to write the network architecture
import torch.nn.functional as F                     #neural network module to write the network architecture
import torchvision as thv                           #torch vision to work on images in the dataset
from torchvision.datasets import MNIST              #library to import/download the MNIST datset
import torchvision.transforms as T                  #torchvision module to do data transformation
from copy import deepcopy

# %% [markdown]
# ## Section 2: Data and it's Preprocessing

# %% [markdown]
# ## Get Data
#
# We provide the dataset in the local MNIST directory. Run the following function `get_data()`to return the training and validation datasets as `train` and `val`. The training images and labels are coupled together and will be called `train` in the `get_data()` method. In the same way, the validation (testing) images and labels are coupled together and will be called `val`.

# %%
def get_data():
    
    """
    return - the training and validation datasets along with their lables. (output type: torchvision dataset)
    """
    train = MNIST('./', download=False, train=True)
    val = MNIST('./', download=False, train=False)

    return train, val

# %%
mnist_train, mnist_val = get_data()

# %% [markdown]
# ## Subsampling of Dataset
# The training dataset contains 60,000 images, and we will select only 30,000 of them. The testing dataset contains 10,000 images, and we will select 5,000 of them. The function `subsample` takes the input of how many samples we want.
#
# Along with subsampling, we will also normalize our dataset by dividing the feature data by 255 (maximum value) because it provides stability while training.

# %%
def subsample(X, Y, num_samples, num_classes):
    """
    X: Feature set, as a 2D numpy array
    Y: Labels, as a 1D numpy array
    num_samples: Total number of samples required after subsampling
    num_classes: Number of unique classes in the dataset
    
    Return: subsampled_X, subsampled_Y subsampled dataset
    """

    # your code here
    
    # Flatten X and change type
    X = X.reshape(X.shape[0], -1).astype(np.float32)

    # Normalize X (divide by 255)
    X = X / 255

    # Calculate the final size of each class
    class_size = num_samples // num_classes

    indices = []

    for label in range(num_classes):
        # Find indices for the given label and select the first class_size elements
        label_indices = np.argwhere(Y == label)[:class_size].flatten()
        # Keep extending the list based upon label indices
        indices.extend(label_indices)

    indices = np.array(indices)

    # Get the subsampled values
    subsampled_X = X[indices]
    subsampled_Y = Y[indices]

    return subsampled_X, subsampled_Y
    #raise NotImplementedError

    ### Uncomment each line of code and complete as needed

    # Flatten X and change type
    # X = X._________(X._________[0], -1).astype(np.float32)                         #use the reshape and the shape function to flatten X data          
    
    # Normalize X
    # X = X / ________                                                               #Normalize with the value of 255
    # Calculate the final size of each class
    # class_size = num_samples // __________                                         #Each class size is given by dividing the total samples by the number of classes
    # indices = []

    # for label in range(num_classes):  
    #     label_indices = np.argwhere(Y == _______)[:class_size].flatten()           # Find indices for the given label and select the first class_size elements           
    #     indices.extend(________)                                                   # Keep on extending the list based upon label indices
    # indices = np.array(indices)
    # subsampled_X = X[_________]                                                    # Get the subsampled values
    # subsampled_Y = Y[_________]                                                    # Get the subsampled values

    # return subsampled_X, subsampled_Y

# %% [markdown]
# ## Calling the subsample two times
# Notice that we have called the `subsample` function twice, once to create the train dataset and once to create the validation dataset.

# %%
trainX, trainY = subsample(X=mnist_train.data.numpy(), Y=mnist_train.targets.numpy(), num_samples=30000, num_classes=10)
valX, valY = subsample(X=mnist_val.data.numpy(), Y=mnist_val.targets.numpy(), num_samples=5000, num_classes=10)

# %%
###############################
##### TEST YOUR CODE HERE #####
###############################

def test_subsample_output_shape(X, Y, num_samples, num_classes):

    subsampled_X, subsampled_Y = subsample(X, Y, num_samples, num_classes)

    assert subsampled_X.shape[0] == num_samples, f"Expected {num_samples} samples, but got {subsampled_X.shape[0]}"
    assert len(subsampled_Y) == num_samples, f"Expected {num_samples} labels, but got {len(subsampled_Y)}"
    
test_subsample_output_shape(X=mnist_train.data.numpy(), Y=mnist_train.targets.numpy(), num_samples=30000, num_classes=10)
print("Output Shape Test Passed for training data")

test_subsample_output_shape(X=mnist_val.data.numpy(), Y=mnist_val.targets.numpy(), num_samples=5000, num_classes=10)
print("Output Shape Test Passed for Validation data")
# Out:
# Output Shape Test Passed for training data
# Output Shape Test Passed for Validation data

# %%
###############################
##### TEST YOUR CODE HERE #####
###############################
def test_subsample_class_distribution(X, Y, num_samples, num_classes):

    subsampled_X, subsampled_Y = subsample(X, Y, num_samples, num_classes)
    
    unique, counts = np.unique(subsampled_Y, return_counts=True)
    expected_class_size = num_samples // num_classes

    for i, label in enumerate(range(num_classes)):
        assert counts[i] == expected_class_size, (
            f"Expected {expected_class_size} samples for class {label}, "
            f"but got {counts[i]}")
        
test_subsample_output_shape(X=mnist_train.data.numpy(), Y=mnist_train.targets.numpy(), num_samples=30000, num_classes=10)
print("Subsample Class Distribution Passed for training data")

test_subsample_output_shape(X=mnist_val.data.numpy(), Y=mnist_val.targets.numpy(), num_samples=5000, num_classes=10)
print("Subsample Class Distribution Passed for Validation data")
# Out:
# Subsample Class Distribution Passed for training data
# Subsample Class Distribution Passed for Validation data

# %%
###############################
##### TEST YOUR CODE HERE #####
###############################
def test_subsample_normalization(X, Y, num_samples, num_classes):

    subsampled_X, _ = subsample(X, Y, num_samples, num_classes)
    
    assert np.all(subsampled_X <= 1.0) and np.all(subsampled_X >= 0.0), (
        "Normalization check failed: Features are not in the range [0, 1]")
    
test_subsample_output_shape(X=mnist_train.data.numpy(), Y=mnist_train.targets.numpy(), num_samples=30000, num_classes=10)
print("Normalization test is passed for training data")

test_subsample_output_shape(X=mnist_val.data.numpy(), Y=mnist_val.targets.numpy(), num_samples=5000, num_classes=10)
print("Normalizaiton test passed for testing data")
# Out:
# Normalization test is passed for training data
# Normalizaiton test passed for testing data

# %% [markdown]
# ## About MNIST dataset
# In this assignment, we are going to work with the MNIST digit dataset. It’s a classic dataset with images of handwritten digits from 0 to 9. It's great for testing and teaching image recognition. Each image is labeled with the correct digit, so it’s a great starting point for experimenting with how well models can recognize and classify numbers. Here we are going to apply this on the neural network we are going to develop using PyTorch.
#
# We will create a custom dataset using the `Dataset` class in PyTorch. It helps us create the dataset which can later be used with the the `DataLoader` class of PyTorch to train and test our models. In Machine Learning (ML) and Deep Learning (DL), the majority of the time is spent working on preparing the data to be used by the model. That involves cleaning the dataset, organizing it, removing missing items, performing some transforms and many other activities. In order to make that job simpler, PyTorch introduced the Dataset class for our purpose - which helps us in creating and transforming our dataset in a customizable way. After the dataset has been created, the next task is to provide the model with small batches of data from the dataset - here in comes the use of DataLoader class which helps us in doing this action quite effectively.
#
# These elements are introduced in the PyTorch Blitz video linked earlier in the notebook; however, for more in-depth reading, see these two tutorials:
#
# * https://pytorch.org/tutorials/beginner/basics/data_tutorial.html.
#
# * https://www.youtube.com/playlist?list=PLqnslRFeH2UrcDBWF5mfPGpqQDSta6VK4 - In this playlist, see video 09.

# %%
class MNISTDataset(Dataset):
    """
    Attributes:
    -----------
    x_data : numpy-array of subsampled Image Input
    y_data : numpy-array of subsampled Labels Input

    Methods:
    --------
    __len__():Returns the number of samples.

    __getitem__(idx):Retrieves the image and label at the given index (Tensor).
    """
    # your code here
    def __init__(self, x_data, y_data):
        # Store images and labels
        self.x_data = x_data
        self.y_data = y_data

    def __len__(self):
        # Return total number of samples
        return len(self.x_data)

    def __getitem__(self, idx):
        # Retrieve data at given index
        x = self.x_data[idx]
        y = self.y_data[idx]
        return x, y
#raise NotImplementedError
    
    ### Uncomment each line of code and complete as needed
    
#     def __init__(self, x_data, y_data):
#         self.x_data = ______                                                 # In the constructor define the images and the labels
#         self.y_data = ________

#     def __len__(self):
#         return len(self.x_data)                                              #The length of the total dataset

#     def __getitem__(self, idx):
#         x = self.x_data[______]                                              #This would ensure the retrieval of new datapoints  
#         y = self.y_data[______]
#         return x, y

# %%
train_dataset = MNISTDataset(trainX, trainY)  
val_dataset = MNISTDataset(valX, valY)

# %%
###############################
##### TEST YOUR CODE HERE #####
###############################

def test_length(x_data, y_data, expected_length):
    dataset = MNISTDataset(x_data, y_data)

    dataset_length = len(dataset)
    assert dataset_length == expected_length, f"Expected dataset length {expected_length}, but got {dataset_length}"
    
test_length(x_data= trainX, y_data=trainY, expected_length = 30000 )
print("The length of the Train dataset is correct")

test_length(x_data= valX, y_data=valY, expected_length = 5000 )
print("The length of the Val dataset is correct")
# Out:
# The length of the Train dataset is correct
# The length of the Val dataset is correct

# %%
###############################
##### TEST YOUR CODE HERE #####
###############################
def test_getitem(x_data, y_data):
    dataset = MNISTDataset(x_data, y_data)

    idx = 1
    expected_x = x_data[idx]
    expected_y = y_data[idx]
    x, y = dataset[idx]

    assert np.array_equal(x, expected_x), f"Expected x at index {idx} to be {expected_x}, but got {x}"
    assert y == expected_y, f"Expected y at index {idx} to be {expected_y}, but got {y}"
    
    
test_getitem(x_data = trainX, y_data=trainY)
print("Data Retrieval of Train dataset is Passed")
test_getitem(x_data = valX, y_data=valY)
print("Data Retrieval of Val dataset is Passed")
# Out:
# Data Retrieval of Train dataset is Passed
# Data Retrieval of Val dataset is Passed

# %% [markdown]
# ## Section 3 Neural Network

# %% [markdown]
# ## Define Neural Network in Pytorch
# Neural networks in PyTorch are created using the `torch.nn` module. The `__init__` method specifies which layers are present in our network. You will notice that in the `__init__` method the linear layer has parameters 784 and 10. This is because we are taking our input dataset, composed of MNIST images of the size 28X28, and converting them to a linear vector of 784. The value 10 represents the number of possible outputs of the MNIST dataset.
#
#
# The `forward` method determines how the data will flow through the network. It shows which elements are applied upon the input data `x` and in what order to perform the forward pass of the datset. In the forward method we are applying `ReLU` upon our dataset after the fully connected layer `fc1`. This is the application of the activation function on our data to bring non-linearity into our model. Non-Linearity is at the heart of what makes neural networks capable of extracting features.

# %%
class Net(nn.Module): 
    """
    A neural network with a single fully connected layer.

    Attributes:
    -----------
    fc1 :Fully connected layer with input size 784 (28X28) and output size 10 (number of samples).

    Methods:
    --------
    forward(x):Applies the forward pass using ReLU activation on the fully connected layer.
    
    Output:
    --------
    out: output of the application of the simple neural network on the dataset
    """ 
    
    # your code here
    
    def __init__(self):
        super(Net, self).__init__()
        # Input: 784 (28x28 flattened), Output: 10 (digit classes 0-9)
        self.fc1 = nn.Linear(784, 10)

    def forward(self, x):
        # Apply ReLU activation after fully connected layer
        out = F.relu(self.fc1(x))
        return out


net = Net()
    #raise NotImplementedError
    
    ### Uncomment each line of code and get the answer
#     def __init__(self):
#         super(Net, self).__init__()
#         self.fc1 = nn.Linear(_____, _____)                                       #Define the sizes of the layer of the NN corresponding to the dataset

#     def forward(self, x):
#         out = F.______(self.fc1(_____))                                           # write out how the data flows through the model
#         return out

# %%
net = Net()

# %%
###############################
##### TEST YOUR CODE HERE #####
###############################
def test_initialization(net):
    assert isinstance(net.fc1, nn.Linear), "fc1 should be an instance of nn.Linear"
    assert net.fc1.in_features == 784, "fc1 input features should be 784"
    assert net.fc1.out_features == 10, "fc1 output features should be 10"
    print("Initialization test passed.")
    
test_initialization(net)
print("The Model is correctly initialized")
# Out:
# Initialization test passed.
# The Model is correctly initialized

# %%
###############################
##### TEST YOUR CODE HERE #####
###############################
def test_forward_pass(net):
    dummy_input = torch.randn(1, 784)
    output = net(dummy_input)
    assert output.shape == (1, 10), "Output shape should be (1, 10)"
    assert output.dtype == torch.float32, "Output dtype should be float32"
    print("Forward pass test passed.")
    
    
test_forward_pass(net)
print("Forward pass is correctly initialized")
# Out:
# Forward pass test passed.
# Forward pass is correctly initialized

# %% [markdown]
# ## Section 4 Training and Evaluation of the Neural Network
# After defining our dataset and our model above, we train and evaluate our model. If you look at the code in this section, you will notice that the validation method, `validate_pytorch_NN`, is defined first and then the training loop, `train_pytorch_nn`. This has been done purposefully, because we are calling the validation function from the training loop. A recommendation is that you start coding from the training loop and then circle back to validation loop.

# %% [markdown]
# ## Validation of Pytorch Neural Network
# Here we have written the `validate_pytorch_NN` method. It takes the trained model, implements it on the testing (validation) dataset, calculates the running loss, and finally outputs the average validation loss and average validation error. Here the key metric is the running loss. During the training and the evaluation (validation) of a neural network, it is run iteratively. The performance is tracked at each iteration, and the record keeping of that is called running loss. We will later plot the loss and the accuracy curves of the model. Those curves are characteristic of the performance of the model.

# %%
def validate_pytorch_NN(net, val_dataloader):
    """
    Validate the PyTorch neural network with the given validation dataloader.
    
    net: The neural network model
    criterion: The loss function
    val_dataloader: DataLoader for the validation data
    
    Return: average validation loss and error
    """

    # your code here
        # Initialize total validation loss and error
    val_loss, val_error = 0, 0
    criterion = nn.CrossEntropyLoss()

    # Iterate over all mini-batches from the validation dataset
    for x_val, y_val in val_dataloader:
        # Convert the data to tensor
        x_val = torch.Tensor(x_val)
        y_val = torch.Tensor(y_val).long()

        # Compute forward pass and error (no gradient tracking needed)
        with torch.no_grad():
            val_out = net(x_val)                                          # Forward pass
            val_loss += criterion(val_out, y_val).item()                  # Running loss
            _, val_pred = torch.max(val_out, 1)                           # Predictions
            val_error += np.sum(
                np.array(val_pred.cpu()) != y_val.cpu().numpy()
            ) / x_val.shape[0]                                            # Running error

    # Compute average validation loss and error
    avg_val_loss = val_loss / len(val_dataloader)
    avg_val_error = val_error / len(val_dataloader)

    return avg_val_loss, avg_val_error
    #raise NotImplementedError

    ### Uncomment each line of code and complete as needed

    # Initialize total validation loss and error
    # val_loss, val_error = 0, 0
#     criterion = nn.CrossEntropyLoss()

    # Iterate over all mini-batches from the validation dataset
    # for x_val, y_val in val_dataloader:
    #     x_val = torch.Tensor(_______)                      # Convert the data to tensor
    #     y_val = torch.Tensor(________)                     # Convert the data to tensor
    #     
    #     # Compute forward pass and error
    #     with torch.no_grad():
    #         val_out = net(______)                                                 #Calculate the output
    #         val_loss += criterion(________, _________).item()                     #Calculate the running loss
    #         _, val_pred = torch.max(_______, 1)                                   # Make the prediction
    #         val_error += np.sum(np.array(_____.cpu()) != _________.cpu().numpy()) / ______.shape[0]  #Calculate the running error 
    # 
    # # Compute average validation loss and error
    # avg_val_loss = _______ / len(_______)                                         #Calculate the average val loss and val error
    # avg_val_error = __________ / len(_________)
    # 
    # return avg_val_loss, avg_val_error

# %% [markdown]
# ## Train Pytorch Neural Network
#
# The training loop in PyTorch teaches your model to make better predictions. Start by passing your data through the model to get predictions. Then calculate how far off these predictions are from the actual values using a loss function. Next, update the model’s parameters to reduce this error, and repeat this process many times. Essentially, the training loop helps the model learn from its mistakes and improve over time.
#
# ### Steps of the Training Loop
# 1. Perform the forward pass on the data where the `model` is applied on the training dataset to generate an ouptut.
# 2. Perform the backpropagation where the gradients are set to zero using `optimizer.zero_grad()` and calculate the backward loss using `loss.backward()`
# 3. Update the model parameters using the `optimizer.step()`

# %%
def train_pytorch_nn(net, train_dataloader, val_dataloader):
    """
    Train a PyTorch neural network with the given parameters.
    
    train_dataloader: DataLoader for the training data
    val_dataloader: DataLoader for the validation data
    lr: Learning rate for the optimizer
    
    Return: Lists of training and validation losses and errors
    """

    # your code here
    # Setup - Do not change these values
    torch.manual_seed(20)
    random.seed(20)
    np.random.seed(20)
    optimizer = optim.SGD(net.parameters(), lr=0.1)
    criterion = nn.CrossEntropyLoss()

    # Initialize tracking lists
    train_error_list = []
    train_loss_list = []
    val_error_list = []
    val_loss_list = []

    # Total iterations to run
    num_iterations = 3050
    iteration = 0

    while iteration < num_iterations:                          # Loop until 3050 iterations
        for x, y in train_dataloader:
            if iteration >= num_iterations:
                break

            x = x
            y = y.long()                                       # Labels must be long type

            # ── Forward Pass ──────────────────────────────────
            outputs = net(x)                                   # Apply network to input
            loss = criterion(outputs, y)                       # Calculate loss
            _, predicted = torch.max(outputs, 1)              # Get predictions
            err = np.sum(
                predicted.cpu().numpy() != y.cpu().numpy()
            ) / x.shape[0]                                     # Calculate error rate

            # ── Backward Pass & Optimization ──────────────────
            optimizer.zero_grad()                              # Zero the gradients
            loss.backward()                                    # Compute gradients
            optimizer.step()                                   # Update weights

            # ── Logging ───────────────────────────────────────
            print(f"Iteration [{iteration}], "
                  f"Loss: {loss.item():.4f}, "
                  f"Error: {err:.4f}, ")

            train_loss_list.append(loss.item())               # Log training loss
            train_error_list.append(err)                      # Log training error

            # ── Validation Step (every 1000 iterations) ───────
            if iteration % 1000 == 0:
                val_loss, val_err = validate_pytorch_NN(net, val_dataloader)
                val_loss_list.append(val_loss)                # Log validation loss
                val_error_list.append(val_err)               # Log validation error

            iteration += 1                                    # Increment counter

    return train_loss_list, train_error_list, val_loss_list, val_error_list
    #raise NotImplementedError

    ### Uncomment each line of code and complete as needed

    # Setup (e.g., seed initialization, if any) - Do not change these values
#     torch.manual_seed(20)
#     random.seed(20)
#     np.random.seed(20)
#     optimizer = optim.SGD(net.parameters(), lr=0.1)
#     criterion = nn.CrossEntropyLoss()


#     train_error_list = []
#     train_loss_list = []
#     val_error_list = []
#     val_loss_list = []

#     # Calculate the total number of batches needed
#     num_iterations = 3050

#     iteration = 0

#     while iteration < ___________:                                                          #write the loop breaking condition such that we can it performs 30,000 iterations
#         for x, y in train_dataloader:
#             if iteration >= num_iterations:
#                 break

#             x = x
#             y = y

#             # Forward pass
#             outputs = net(____)                                            #network is applied on input data
#             loss = criterion(______, _____)                                # running loss is calculated
#             _, predicted = torch.max(______, 1)                            # Model class predictions are taken
#             err = np.sum(_______.cpu().numpy() != _________.cpu().numpy()) / x.shape[0]   #Running error of the model is calculated

#             # Backward pass and optimization
#             optimizer._______grad()                                                       # Zero gradients
#             loss.___________()                                                            #calculate the loss values
#             optimizer.__________()                                                        #take the next optimization step

#             # Logging
#             print(f"Iteration [{iteration}], "
#             f"Loss: {loss.item():.4f}, "
#             f"Error: {err:.4f}, ")
#             train_loss_list.append(________.item())                                       # log the loss value
#             train_error_list.append(______)                                               # log the error value

#             # Validation step
#             if iteration % 1000 == 0:                                                      #validation step at every 500 iteration
#                 val_loss, val_err = validate_pytorch_NN(net, val_dataloader) 
#                 val_loss_list.append(______)                                              # log the validaiton loss value
#                 val_error_list.append(__________)                                         # log the validation error value

#             iteration += ___                                                              #increment iteration

#     return train_loss_list, train_error_list, val_loss_list, val_error_list

# %%
train_dataset = MNISTDataset(trainX, trainY) 
train_dataloader = DataLoader(train_dataset, batch_size=64, shuffle=True)

val_dataset = MNISTDataset(valX, valY)
val_dataloader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# %%
train_loss_list, train_error_list, val_loss_list, val_error_list = train_pytorch_nn(net, train_dataloader, val_dataloader)
# Out:
# Iteration [0], Loss: 2.2952, Error: 0.8594,
# Iteration [1], Loss: 2.2511, Error: 0.7656,
# Iteration [2], Loss: 2.2610, Error: 0.8281,
# Iteration [3], Loss: 2.2515, Error: 0.8438,
# Iteration [4], Loss: 2.1962, Error: 0.6875,
# Iteration [5], Loss: 2.1685, Error: 0.7969,
# Iteration [6], Loss: 2.1718, Error: 0.7969,
# Iteration [7], Loss: 2.0956, Error: 0.6250,
# Iteration [8], Loss: 1.9734, Error: 0.5312,
# Iteration [9], Loss: 1.9069, Error: 0.4844,
# Iteration [10], Loss: 1.9682, Error: 0.5312,
# Iteration [11], Loss: 1.9045, Error: 0.5312,
# Iteration [12], Loss: 1.7940, Error: 0.5000,
# Iteration [13], Loss: 1.9013, Error: 0.5781,
# Iteration [14], Loss: 1.8215, Error: 0.5156,
# Iteration [15], Loss: 1.7969, Error: 0.5000,
# Iteration [16], Loss: 1.6984, Error: 0.4219,
# Iteration [17], Loss: 1.7380, Error: 0.4531,
# Iteration [18], Loss: 1.5677, Error: 0.3906,
# Iteration [19], Loss: 1.6106, Error: 0.3750,
# Iteration [20], Loss: 1.6517, Error: 0.4688,
# Iteration [21], Loss: 1.6184, Error: 0.4375,
# Iteration [22], Loss: 1.4382, Error: 0.3125,
# Iteration [23], Loss: 1.4532, Error: 0.3594,
# Iteration [24], Loss: 1.6594, Error: 0.4375,
# Iteration [25], Loss: 1.3456, Error: 0.2656,
# Iteration [26], Loss: 1.4515, Error: 0.2812,
# Iteration [27], Loss: 1.5196, Error: 0.3438,
# Iteration [28], Loss: 1.6648, Error: 0.4375,
# Iteration [29], Loss: 1.4107, Error: 0.2656,
# Iteration [30], Loss: 1.3685, Error: 0.3281,
# Iteration [31], Loss: 1.3837, Error: 0.3438,
# Iteration [32], Loss: 1.3264, Error: 0.3125,
# Iteration [33], Loss: 1.4357, Error: 0.3281,
# Iteration [34], Loss: 1.4091, Error: 0.3906,
# Iteration [35], Loss: 1.3963, Error: 0.4062,
# Iteration [36], Loss: 1.1987, Error: 0.2500,
# Iteration [37], Loss: 1.3370, Error: 0.3438,
# Iteration [38], Loss: 1.1881, Error: 0.2812,
# Iteration [39], Loss: 1.1369, Error: 0.2656,
# Iteration [40], Loss: 1.2148, Error: 0.2812,
# Iteration [41], Loss: 1.3058, Error: 0.3281,
# Iteration [42], Loss: 1.3496, Error: 0.4062,
# Iteration [43], Loss: 1.3430, Error: 0.3125,
# Iteration [44], Loss: 1.3724, Error: 0.3906,
# Iteration [45], Loss: 1.3434, Error: 0.3281,
# Iteration [46], Loss: 1.2395, Error: 0.2812,
# Iteration [47], Loss: 1.1139, Error: 0.2500,
# Iteration [48], Loss: 1.1968, Error: 0.3125,
# Iteration [49], Loss: 1.1865, Error: 0.3438,
# Iteration [50], Loss: 1.3235, Error: 0.3594,
# Iteration [51], Loss: 1.1585, Error: 0.2656,
# Iteration [52], Loss: 1.0830, Error: 0.2656,
# Iteration [53], Loss: 1.1956, Error: 0.3281,
# Iteration [54], Loss: 1.3148, Error: 0.3594,
# Iteration [55], Loss: 1.2226, Error: 0.3281,
# Iteration [56], Loss: 1.0975, Error: 0.3125,
# Iteration [57], Loss: 1.1324, Error: 0.3438,
# Iteration [58], Loss: 0.8945, Error: 0.2031,
# Iteration [59], Loss: 1.2811, Error: 0.3750,
# Iteration [60], Loss: 1.3848, Error: 0.4219,
# Iteration [61], Loss: 1.3485, Error: 0.4062,
# Iteration [62], Loss: 1.0624, Error: 0.2969,
# Iteration [63], Loss: 1.2194, Error: 0.3594,
# Iteration [64], Loss: 1.3927, Error: 0.4375,
# Iteration [65], Loss: 1.1107, Error: 0.2969,
# Iteration [66], Loss: 1.0539, Error: 0.3125,
# Iteration [67], Loss: 1.2311, Error: 0.3594,
# Iteration [68], Loss: 1.1807, Error: 0.3125,
# Iteration [69], Loss: 1.0226, Error: 0.2344,
# Iteration [70], Loss: 1.1890, Error: 0.3125,
# Iteration [71], Loss: 0.9491, Error: 0.2500,
# Iteration [72], Loss: 1.0161, Error: 0.2812,
# Iteration [73], Loss: 1.4095, Error: 0.4688,
# Iteration [74], Loss: 1.1066, Error: 0.2969,
# Iteration [75], Loss: 1.1889, Error: 0.2969,
# Iteration [76], Loss: 1.0807, Error: 0.2812,
# Iteration [77], Loss: 1.3136, Error: 0.4062,
# Iteration [78], Loss: 0.8742, Error: 0.2031,
# Iteration [79], Loss: 1.1730, Error: 0.3438,
# Iteration [80], Loss: 1.1361, Error: 0.3594,
# Iteration [81], Loss: 1.2018, Error: 0.3125,
# Iteration [82], Loss: 1.2594, Error: 0.3594,
# Iteration [83], Loss: 0.9644, Error: 0.2500,
# Iteration [84], Loss: 1.0262, Error: 0.2969,
# Iteration [85], Loss: 0.8962, Error: 0.2031,
# Iteration [86], Loss: 1.0898, Error: 0.3281,
# Iteration [87], Loss: 1.2904, Error: 0.4062,
# Iteration [88], Loss: 1.0089, Error: 0.2812,
# Iteration [89], Loss: 0.7882, Error: 0.1875,
# Iteration [90], Loss: 0.9611, Error: 0.2344,
# Iteration [91], Loss: 1.0260, Error: 0.2812,
# Iteration [92], Loss: 0.9909, Error: 0.2812,
# Iteration [93], Loss: 1.0563, Error: 0.2969,
# Iteration [94], Loss: 0.8248, Error: 0.1719,
# Iteration [95], Loss: 0.9275, Error: 0.2656,
# Iteration [96], Loss: 1.0663, Error: 0.2812,
# Iteration [97], Loss: 1.2291, Error: 0.3594,
# Iteration [98], Loss: 1.0951, Error: 0.3438,
# Iteration [99], Loss: 0.9502, Error: 0.2656,
# Iteration [100], Loss: 1.1410, Error: 0.3125,
# Iteration [101], Loss: 1.0428, Error: 0.2812,
# Iteration [102], Loss: 0.9840, Error: 0.3125,
# Iteration [103], Loss: 1.0595, Error: 0.3281,
# Iteration [104], Loss: 1.0669, Error: 0.2969,
# Iteration [105], Loss: 1.1606, Error: 0.3281,
# Iteration [106], Loss: 1.0748, Error: 0.3125,
# Iteration [107], Loss: 1.1276, Error: 0.3594,
# Iteration [108], Loss: 0.9545, Error: 0.2344,
# Iteration [109], Loss: 1.0129, Error: 0.2969,
# Iteration [110], Loss: 1.2053, Error: 0.3438,
# Iteration [111], Loss: 0.8361, Error: 0.2344,
# Iteration [112], Loss: 1.2175, Error: 0.3125,
# Iteration [113], Loss: 0.8965, Error: 0.2500,
# Iteration [114], Loss: 0.7929, Error: 0.2031,
# Iteration [115], Loss: 0.8389, Error: 0.2344,
# Iteration [116], Loss: 0.9462, Error: 0.2969,
# Iteration [117], Loss: 1.1340, Error: 0.3594,
# Iteration [118], Loss: 1.0920, Error: 0.3281,
# Iteration [119], Loss: 0.9945, Error: 0.2969,
# Iteration [120], Loss: 1.0619, Error: 0.3125,
# Iteration [121], Loss: 1.0360, Error: 0.3125,
# Iteration [122], Loss: 1.0746, Error: 0.3281,
# Iteration [123], Loss: 1.1203, Error: 0.3438,
# Iteration [124], Loss: 1.0489, Error: 0.3438,
# Iteration [125], Loss: 1.1258, Error: 0.3281,
# Iteration [126], Loss: 0.9381, Error: 0.2500,
# Iteration [127], Loss: 0.8756, Error: 0.2500,
# Iteration [128], Loss: 0.9782, Error: 0.2500,
# Iteration [129], Loss: 0.9808, Error: 0.3438,
# Iteration [130], Loss: 0.9572, Error: 0.2656,
# Iteration [131], Loss: 1.0411, Error: 0.2656,
# Iteration [132], Loss: 1.0683, Error: 0.2969,
# Iteration [133], Loss: 1.1145, Error: 0.3438,
# Iteration [134], Loss: 0.8414, Error: 0.2031,
# Iteration [135], Loss: 0.8403, Error: 0.2500,
# Iteration [136], Loss: 0.8777, Error: 0.2188,
# Iteration [137], Loss: 1.0091, Error: 0.2969,
# Iteration [138], Loss: 0.9473, Error: 0.2344,
# Iteration [139], Loss: 1.1387, Error: 0.3438,
# Iteration [140], Loss: 1.3483, Error: 0.3906,
# Iteration [141], Loss: 1.0209, Error: 0.2969,
# Iteration [142], Loss: 1.1023, Error: 0.3281,
# Iteration [143], Loss: 0.7506, Error: 0.1875,
# Iteration [144], Loss: 0.9604, Error: 0.2812,
# Iteration [145], Loss: 0.8497, Error: 0.2031,
# Iteration [146], Loss: 1.1513, Error: 0.3594,
# Iteration [147], Loss: 0.7963, Error: 0.2188,
# Iteration [148], Loss: 1.0861, Error: 0.3438,
# Iteration [149], Loss: 0.9884, Error: 0.3125,
# Iteration [150], Loss: 0.8489, Error: 0.2656,
# Iteration [151], Loss: 0.9070, Error: 0.2656,
# Iteration [152], Loss: 1.0688, Error: 0.3125,
# Iteration [153], Loss: 0.9722, Error: 0.2969,
# Iteration [154], Loss: 0.9739, Error: 0.2500,
# Iteration [155], Loss: 0.9989, Error: 0.3125,
# Iteration [156], Loss: 0.9291, Error: 0.2969,
# Iteration [157], Loss: 1.2632, Error: 0.3750,
# Iteration [158], Loss: 1.2553, Error: 0.3594,
# Iteration [159], Loss: 1.0121, Error: 0.3125,
# Iteration [160], Loss: 0.8861, Error: 0.2656,
# Iteration [161], Loss: 1.0754, Error: 0.3281,
# Iteration [162], Loss: 1.0167, Error: 0.3125,
# Iteration [163], Loss: 0.8065, Error: 0.2031,
# Iteration [164], Loss: 0.9672, Error: 0.2969,
# Iteration [165], Loss: 1.0408, Error: 0.3281,
# Iteration [166], Loss: 0.8342, Error: 0.2500,
# Iteration [167], Loss: 0.9265, Error: 0.2656,
# Iteration [168], Loss: 1.1909, Error: 0.4062,
# Iteration [169], Loss: 1.1959, Error: 0.3438,
# Iteration [170], Loss: 0.8397, Error: 0.2344,
# Iteration [171], Loss: 1.0455, Error: 0.3281,
# Iteration [172], Loss: 0.7698, Error: 0.2031,
# Iteration [173], Loss: 1.0414, Error: 0.3125,
# Iteration [174], Loss: 0.7424, Error: 0.2188,
# Iteration [175], Loss: 0.8540, Error: 0.2344,
# Iteration [176], Loss: 0.9316, Error: 0.2969,
# Iteration [177], Loss: 0.7244, Error: 0.2188,
# Iteration [178], Loss: 1.0665, Error: 0.3594,
# Iteration [179], Loss: 0.8841, Error: 0.2344,
# Iteration [180], Loss: 0.9673, Error: 0.2812,
# Iteration [181], Loss: 1.0172, Error: 0.2969,
# Iteration [182], Loss: 1.0401, Error: 0.3281,
# Iteration [183], Loss: 0.9215, Error: 0.2812,
# Iteration [184], Loss: 0.8884, Error: 0.2656,
# Iteration [185], Loss: 1.1209, Error: 0.3594,
# Iteration [186], Loss: 0.9007, Error: 0.2656,
# Iteration [187], Loss: 0.8985, Error: 0.2812,
# Iteration [188], Loss: 0.7432, Error: 0.1875,
# Iteration [189], Loss: 0.9096, Error: 0.2656,
# Iteration [190], Loss: 1.0362, Error: 0.3438,
# Iteration [191], Loss: 0.9476, Error: 0.2500,
# Iteration [192], Loss: 1.2746, Error: 0.4062,
# Iteration [193], Loss: 0.8718, Error: 0.2812,
# Iteration [194], Loss: 1.0584, Error: 0.3438,
# Iteration [195], Loss: 0.9125, Error: 0.2500,
# Iteration [196], Loss: 1.0642, Error: 0.3594,
# Iteration [197], Loss: 0.8270, Error: 0.2188,
# Iteration [198], Loss: 0.7835, Error: 0.2344,
# Iteration [199], Loss: 0.8240, Error: 0.2656,
# Iteration [200], Loss: 1.0076, Error: 0.3281,
# Iteration [201], Loss: 1.1081, Error: 0.3281,
# Iteration [202], Loss: 0.9930, Error: 0.3438,
# Iteration [203], Loss: 1.0730, Error: 0.3594,
# Iteration [204], Loss: 0.9162, Error: 0.2656,
# Iteration [205], Loss: 0.9475, Error: 0.2812,
# Iteration [206], Loss: 0.6996, Error: 0.2188,
# Iteration [207], Loss: 0.8502, Error: 0.2656,
# Iteration [208], Loss: 0.7349, Error: 0.1719,
# Iteration [209], Loss: 0.9001, Error: 0.2969,
# Iteration [210], Loss: 1.0725, Error: 0.3438,
# Iteration [211], Loss: 0.9109, Error: 0.2656,
# Iteration [212], Loss: 0.6723, Error: 0.1719,
# Iteration [213], Loss: 1.0095, Error: 0.3125,
# Iteration [214], Loss: 0.7566, Error: 0.2031,
# Iteration [215], Loss: 0.9582, Error: 0.3125,
# Iteration [216], Loss: 0.9004, Error: 0.2656,
# Iteration [217], Loss: 0.8965, Error: 0.2969,
# Iteration [218], Loss: 1.2171, Error: 0.4062,
# Iteration [219], Loss: 0.9010, Error: 0.2812,
# Iteration [220], Loss: 0.7676, Error: 0.2031,
# Iteration [221], Loss: 0.9266, Error: 0.2812,
# Iteration [222], Loss: 0.9817, Error: 0.3281,
# Iteration [223], Loss: 0.8557, Error: 0.2656,
# Iteration [224], Loss: 0.8993, Error: 0.2969,
# Iteration [225], Loss: 0.8655, Error: 0.2500,
# Iteration [226], Loss: 0.8502, Error: 0.2812,
# Iteration [227], Loss: 1.0988, Error: 0.3125,
# Iteration [228], Loss: 1.1530, Error: 0.3750,
# Iteration [229], Loss: 0.7200, Error: 0.2031,
# Iteration [230], Loss: 0.8957, Error: 0.2812,
# Iteration [231], Loss: 0.9943, Error: 0.3281,
# Iteration [232], Loss: 0.8064, Error: 0.2812,
# Iteration [233], Loss: 1.1488, Error: 0.4219,
# Iteration [234], Loss: 0.8836, Error: 0.2656,
# Iteration [235], Loss: 0.9662, Error: 0.2969,
# Iteration [236], Loss: 0.8140, Error: 0.2188,
# Iteration [237], Loss: 0.9249, Error: 0.3125,
# Iteration [238], Loss: 0.8663, Error: 0.2656,
# Iteration [239], Loss: 0.8020, Error: 0.2500,
# Iteration [240], Loss: 1.0014, Error: 0.3125,
# Iteration [241], Loss: 0.8625, Error: 0.2500,
# Iteration [242], Loss: 0.7449, Error: 0.2500,
# Iteration [243], Loss: 1.0528, Error: 0.3594,
# Iteration [244], Loss: 0.8179, Error: 0.2344,
# Iteration [245], Loss: 1.1690, Error: 0.4219,
# Iteration [246], Loss: 0.8173, Error: 0.2344,
# Iteration [247], Loss: 1.0281, Error: 0.2969,
# Iteration [248], Loss: 0.9880, Error: 0.3125,
# Iteration [249], Loss: 0.8991, Error: 0.2812,
# Iteration [250], Loss: 0.9505, Error: 0.2656,
# Iteration [251], Loss: 0.9280, Error: 0.3125,
# Iteration [252], Loss: 0.8772, Error: 0.2500,
# Iteration [253], Loss: 1.0398, Error: 0.3125,
# Iteration [254], Loss: 0.8024, Error: 0.2344,
# Iteration [255], Loss: 0.9839, Error: 0.3125,
# Iteration [256], Loss: 1.0362, Error: 0.3594,
# Iteration [257], Loss: 0.8563, Error: 0.2656,
# Iteration [258], Loss: 0.8802, Error: 0.2812,
# Iteration [259], Loss: 1.0008, Error: 0.2969,
# Iteration [260], Loss: 0.8395, Error: 0.2344,
# Iteration [261], Loss: 0.8686, Error: 0.2656,
# Iteration [262], Loss: 1.0512, Error: 0.3594,
# Iteration [263], Loss: 0.7669, Error: 0.2500,
# Iteration [264], Loss: 1.0133, Error: 0.3125,
# Iteration [265], Loss: 0.9835, Error: 0.3125,
# Iteration [266], Loss: 1.0041, Error: 0.3438,
# Iteration [267], Loss: 0.7234, Error: 0.2031,
# Iteration [268], Loss: 0.9467, Error: 0.2969,
# Iteration [269], Loss: 0.9853, Error: 0.3438,
# Iteration [270], Loss: 1.1262, Error: 0.3906,
# Iteration [271], Loss: 0.8572, Error: 0.2812,
# Iteration [272], Loss: 1.0391, Error: 0.3438,
# Iteration [273], Loss: 0.9521, Error: 0.3281,
# Iteration [274], Loss: 1.0873, Error: 0.3438,
# Iteration [275], Loss: 0.7904, Error: 0.2812,
# Iteration [276], Loss: 0.7145, Error: 0.2031,
# Iteration [277], Loss: 0.7651, Error: 0.2344,
# Iteration [278], Loss: 0.7285, Error: 0.2344,
# Iteration [279], Loss: 1.1290, Error: 0.3594,
# Iteration [280], Loss: 0.8671, Error: 0.2500,
# Iteration [281], Loss: 0.7818, Error: 0.2656,
# Iteration [282], Loss: 0.8127, Error: 0.2656,
# Iteration [283], Loss: 0.8700, Error: 0.2656,
# Iteration [284], Loss: 0.9767, Error: 0.2969,
# Iteration [285], Loss: 0.9785, Error: 0.3125,
# Iteration [286], Loss: 0.6456, Error: 0.2031,
# Iteration [287], Loss: 0.9243, Error: 0.2656,
# Iteration [288], Loss: 0.7300, Error: 0.2031,
# Iteration [289], Loss: 0.8686, Error: 0.2656,
# Iteration [290], Loss: 0.9997, Error: 0.3125,
# Iteration [291], Loss: 0.9629, Error: 0.2969,
# Iteration [292], Loss: 0.7088, Error: 0.2188,
# Iteration [293], Loss: 0.9613, Error: 0.2969,
# Iteration [294], Loss: 0.7806, Error: 0.2031,
# Iteration [295], Loss: 0.8372, Error: 0.2500,
# Iteration [296], Loss: 1.0125, Error: 0.3594,
# Iteration [297], Loss: 1.1123, Error: 0.4062,
# Iteration [298], Loss: 1.0513, Error: 0.3750,
# Iteration [299], Loss: 0.8398, Error: 0.2969,
# Iteration [300], Loss: 0.9842, Error: 0.2969,
# Iteration [301], Loss: 0.9839, Error: 0.3125,
# Iteration [302], Loss: 1.0011, Error: 0.3125,
# Iteration [303], Loss: 0.9871, Error: 0.3125,
# Iteration [304], Loss: 0.9449, Error: 0.2500,
# Iteration [305], Loss: 1.0238, Error: 0.3281,
# Iteration [306], Loss: 0.9556, Error: 0.2969,
# Iteration [307], Loss: 0.8075, Error: 0.2812,
# Iteration [308], Loss: 0.7336, Error: 0.1875,
# Iteration [309], Loss: 1.0865, Error: 0.3438,
# Iteration [310], Loss: 0.8506, Error: 0.2656,
# Iteration [311], Loss: 0.8699, Error: 0.2812,
# Iteration [312], Loss: 0.9631, Error: 0.2969,
# Iteration [313], Loss: 0.8015, Error: 0.2656,
# Iteration [314], Loss: 0.7311, Error: 0.2188,
# Iteration [315], Loss: 0.9835, Error: 0.2969,
# Iteration [316], Loss: 1.1120, Error: 0.3750,
# Iteration [317], Loss: 0.6529, Error: 0.1562,
# Iteration [318], Loss: 0.7283, Error: 0.2188,
# Iteration [319], Loss: 0.9386, Error: 0.3125,
# Iteration [320], Loss: 0.8866, Error: 0.3125,
# Iteration [321], Loss: 0.7103, Error: 0.1875,
# Iteration [322], Loss: 0.8346, Error: 0.2969,
# Iteration [323], Loss: 0.9876, Error: 0.2969,
# Iteration [324], Loss: 0.7392, Error: 0.2031,
# Iteration [325], Loss: 1.0627, Error: 0.3594,
# Iteration [326], Loss: 0.7993, Error: 0.2344,
# Iteration [327], Loss: 1.0214, Error: 0.3750,
# Iteration [328], Loss: 0.6828, Error: 0.2344,
# Iteration [329], Loss: 1.0458, Error: 0.3281,
# Iteration [330], Loss: 0.7935, Error: 0.2500,
# Iteration [331], Loss: 0.8647, Error: 0.2969,
# Iteration [332], Loss: 1.0112, Error: 0.3438,
# Iteration [333], Loss: 0.6830, Error: 0.2500,
# Iteration [334], Loss: 0.8059, Error: 0.2812,
# Iteration [335], Loss: 1.0490, Error: 0.2812,
# Iteration [336], Loss: 0.8750, Error: 0.2812,
# Iteration [337], Loss: 0.5599, Error: 0.1250,
# Iteration [338], Loss: 0.9006, Error: 0.2969,
# Iteration [339], Loss: 0.7618, Error: 0.1875,
# Iteration [340], Loss: 1.0066, Error: 0.3750,
# Iteration [341], Loss: 0.7261, Error: 0.2188,
# Iteration [342], Loss: 0.8894, Error: 0.3281,
# Iteration [343], Loss: 0.9319, Error: 0.3281,
# Iteration [344], Loss: 0.7648, Error: 0.2344,
# Iteration [345], Loss: 0.6159, Error: 0.1406,
# Iteration [346], Loss: 0.8906, Error: 0.2500,
# Iteration [347], Loss: 0.6930, Error: 0.2500,
# Iteration [348], Loss: 1.1301, Error: 0.3594,
# Iteration [349], Loss: 0.8484, Error: 0.2812,
# Iteration [350], Loss: 0.6571, Error: 0.2188,
# Iteration [351], Loss: 0.7308, Error: 0.2344,
# Iteration [352], Loss: 1.0123, Error: 0.3281,
# Iteration [353], Loss: 0.8484, Error: 0.2656,
# Iteration [354], Loss: 0.8983, Error: 0.2656,
# Iteration [355], Loss: 0.8791, Error: 0.2812,
# Iteration [356], Loss: 0.9164, Error: 0.2344,
# Iteration [357], Loss: 0.7519, Error: 0.1875,
# Iteration [358], Loss: 0.8595, Error: 0.1719,
# Iteration [359], Loss: 0.8414, Error: 0.2188,
# Iteration [360], Loss: 0.8340, Error: 0.2031,
# Iteration [361], Loss: 0.6467, Error: 0.2188,
# Iteration [362], Loss: 0.7310, Error: 0.2031,
# Iteration [363], Loss: 0.6424, Error: 0.1562,
# Iteration [364], Loss: 0.8478, Error: 0.2344,
# Iteration [365], Loss: 0.7761, Error: 0.2188,
# Iteration [366], Loss: 0.8580, Error: 0.1719,
# Iteration [367], Loss: 0.6405, Error: 0.1406,
# Iteration [368], Loss: 0.9760, Error: 0.2188,
# Iteration [369], Loss: 0.8323, Error: 0.2188,
# Iteration [370], Loss: 0.7487, Error: 0.1562,
# Iteration [371], Loss: 0.7140, Error: 0.1875,
# Iteration [372], Loss: 0.7488, Error: 0.1875,
# Iteration [373], Loss: 0.7283, Error: 0.2344,
# Iteration [374], Loss: 0.7438, Error: 0.2656,
# Iteration [375], Loss: 0.6945, Error: 0.1562,
# Iteration [376], Loss: 0.5200, Error: 0.0938,
# Iteration [377], Loss: 0.7106, Error: 0.2188,
# Iteration [378], Loss: 1.0174, Error: 0.2969,
# Iteration [379], Loss: 0.8984, Error: 0.2812,
# Iteration [380], Loss: 0.9848, Error: 0.2656,
# Iteration [381], Loss: 0.6319, Error: 0.2031,
# Iteration [382], Loss: 0.9389, Error: 0.3125,
# Iteration [383], Loss: 0.8506, Error: 0.2344,
# Iteration [384], Loss: 0.9539, Error: 0.2969,
# Iteration [385], Loss: 0.5971, Error: 0.1562,
# Iteration [386], Loss: 0.7738, Error: 0.2500,
# Iteration [387], Loss: 0.8057, Error: 0.2188,
# Iteration [388], Loss: 0.6437, Error: 0.1719,
# Iteration [389], Loss: 0.4336, Error: 0.1250,
# Iteration [390], Loss: 0.8021, Error: 0.2656,
# Iteration [391], Loss: 0.6925, Error: 0.2031,
# Iteration [392], Loss: 0.7572, Error: 0.2031,
# Iteration [393], Loss: 0.9231, Error: 0.2656,
# Iteration [394], Loss: 0.9416, Error: 0.2969,
# Iteration [395], Loss: 0.6250, Error: 0.1562,
# Iteration [396], Loss: 0.7654, Error: 0.2031,
# Iteration [397], Loss: 0.6879, Error: 0.1875,
# Iteration [398], Loss: 0.6425, Error: 0.1875,
# Iteration [399], Loss: 0.5791, Error: 0.1562,
# Iteration [400], Loss: 0.7310, Error: 0.1875,
# Iteration [401], Loss: 0.7407, Error: 0.2344,
# Iteration [402], Loss: 0.8218, Error: 0.2031,
# Iteration [403], Loss: 0.7337, Error: 0.2188,
# Iteration [404], Loss: 0.8156, Error: 0.2031,
# Iteration [405], Loss: 0.6786, Error: 0.1875,
# Iteration [406], Loss: 0.6119, Error: 0.1719,
# Iteration [407], Loss: 0.8220, Error: 0.2188,
# Iteration [408], Loss: 0.6729, Error: 0.2031,
# Iteration [409], Loss: 0.8780, Error: 0.2344,
# Iteration [410], Loss: 0.6895, Error: 0.1719,
# Iteration [411], Loss: 0.6968, Error: 0.2188,
# Iteration [412], Loss: 0.6459, Error: 0.2031,
# Iteration [413], Loss: 0.8375, Error: 0.2656,
# Iteration [414], Loss: 0.6443, Error: 0.2031,
# Iteration [415], Loss: 0.6320, Error: 0.1719,
# Iteration [416], Loss: 0.7248, Error: 0.2344,
# Iteration [417], Loss: 0.7886, Error: 0.2188,
# Iteration [418], Loss: 0.6123, Error: 0.1406,
# Iteration [419], Loss: 0.5545, Error: 0.1875,
# Iteration [420], Loss: 0.5307, Error: 0.1719,
# Iteration [421], Loss: 0.6885, Error: 0.1875,
# Iteration [422], Loss: 0.6434, Error: 0.2031,
# Iteration [423], Loss: 0.6127, Error: 0.1562,
# Iteration [424], Loss: 0.7911, Error: 0.2344,
# Iteration [425], Loss: 0.6455, Error: 0.1875,
# Iteration [426], Loss: 0.7257, Error: 0.2188,
# Iteration [427], Loss: 0.6050, Error: 0.1719,
# Iteration [428], Loss: 0.4412, Error: 0.0625,
# Iteration [429], Loss: 0.7574, Error: 0.2031,
# Iteration [430], Loss: 0.7216, Error: 0.2188,
# Iteration [431], Loss: 0.6339, Error: 0.1250,
# Iteration [432], Loss: 0.5480, Error: 0.1719,
# Iteration [433], Loss: 0.6338, Error: 0.1562,
# Iteration [434], Loss: 0.6900, Error: 0.1719,
# Iteration [435], Loss: 0.7960, Error: 0.2188,
# Iteration [436], Loss: 0.6418, Error: 0.2188,
# Iteration [437], Loss: 0.4889, Error: 0.1406,
# Iteration [438], Loss: 0.7270, Error: 0.2031,
# Iteration [439], Loss: 0.6978, Error: 0.2031,
# Iteration [440], Loss: 0.7948, Error: 0.2031,
# Iteration [441], Loss: 0.5216, Error: 0.1562,
# Iteration [442], Loss: 0.9085, Error: 0.2812,
# Iteration [443], Loss: 0.6389, Error: 0.1875,
# Iteration [444], Loss: 0.5856, Error: 0.1562,
# Iteration [445], Loss: 0.6961, Error: 0.2031,
# Iteration [446], Loss: 0.8890, Error: 0.2812,
# Iteration [447], Loss: 0.4412, Error: 0.0938,
# Iteration [448], Loss: 0.9411, Error: 0.2812,
# Iteration [449], Loss: 0.6734, Error: 0.2031,
# Iteration [450], Loss: 0.6520, Error: 0.1719,
# Iteration [451], Loss: 0.9228, Error: 0.2812,
# Iteration [452], Loss: 0.7839, Error: 0.2500,
# Iteration [453], Loss: 0.7872, Error: 0.2188,
# Iteration [454], Loss: 0.6870, Error: 0.2188,
# Iteration [455], Loss: 0.5631, Error: 0.1562,
# Iteration [456], Loss: 0.6221, Error: 0.1562,
# Iteration [457], Loss: 0.7417, Error: 0.2188,
# Iteration [458], Loss: 0.7229, Error: 0.2344,
# Iteration [459], Loss: 0.5957, Error: 0.2031,
# Iteration [460], Loss: 0.6935, Error: 0.1719,
# Iteration [461], Loss: 0.5985, Error: 0.1875,
# Iteration [462], Loss: 0.7038, Error: 0.2031,
# Iteration [463], Loss: 0.4809, Error: 0.1250,
# Iteration [464], Loss: 0.7355, Error: 0.2344,
# Iteration [465], Loss: 0.6659, Error: 0.2188,
# Iteration [466], Loss: 0.5742, Error: 0.1406,
# Iteration [467], Loss: 0.8304, Error: 0.2344,
# Iteration [468], Loss: 0.7397, Error: 0.2083,
# Iteration [469], Loss: 0.7439, Error: 0.2344,
# Iteration [470], Loss: 0.8178, Error: 0.2500,
# Iteration [471], Loss: 0.5660, Error: 0.1562,
# Iteration [472], Loss: 0.5651, Error: 0.1719,
# Iteration [473], Loss: 0.7419, Error: 0.2500,
# Iteration [474], Loss: 0.5891, Error: 0.1875,
# Iteration [475], Loss: 0.5604, Error: 0.1719,
# Iteration [476], Loss: 0.5877, Error: 0.1719,
# Iteration [477], Loss: 0.7869, Error: 0.2188,
# Iteration [478], Loss: 0.7349, Error: 0.1875,
# Iteration [479], Loss: 0.5392, Error: 0.1562,
# Iteration [480], Loss: 0.4911, Error: 0.1406,
# Iteration [481], Loss: 0.6598, Error: 0.2188,
# Iteration [482], Loss: 0.6927, Error: 0.1562,
# Iteration [483], Loss: 0.6391, Error: 0.2188,
# Iteration [484], Loss: 0.5092, Error: 0.1250,
# Iteration [485], Loss: 0.6309, Error: 0.1562,
# Iteration [486], Loss: 0.4781, Error: 0.1250,
# Iteration [487], Loss: 0.4160, Error: 0.1250,
# Iteration [488], Loss: 0.7582, Error: 0.2656,
# Iteration [489], Loss: 0.3842, Error: 0.0938,
# Iteration [490], Loss: 0.6636, Error: 0.2188,
# Iteration [491], Loss: 0.7547, Error: 0.2188,
# Iteration [492], Loss: 0.5976, Error: 0.1562,
# Iteration [493], Loss: 0.6671, Error: 0.1719,
# Iteration [494], Loss: 0.6301, Error: 0.1719,
# Iteration [495], Loss: 0.5305, Error: 0.1719,
# Iteration [496], Loss: 0.6140, Error: 0.1875,
# Iteration [497], Loss: 0.4878, Error: 0.1250,
# Iteration [498], Loss: 0.7023, Error: 0.2031,
# Iteration [499], Loss: 0.6119, Error: 0.1719,
# Iteration [500], Loss: 0.7386, Error: 0.2344,
# Iteration [501], Loss: 0.4180, Error: 0.1094,
# Iteration [502], Loss: 0.5471, Error: 0.1562,
# Iteration [503], Loss: 0.5420, Error: 0.1562,
# Iteration [504], Loss: 0.7333, Error: 0.2188,
# Iteration [505], Loss: 0.7306, Error: 0.2188,
# Iteration [506], Loss: 0.4312, Error: 0.1250,
# Iteration [507], Loss: 0.7249, Error: 0.2344,
# Iteration [508], Loss: 0.8294, Error: 0.1875,
# Iteration [509], Loss: 0.6423, Error: 0.1719,
# Iteration [510], Loss: 0.5166, Error: 0.1250,
# Iteration [511], Loss: 0.5306, Error: 0.1562,
# Iteration [512], Loss: 0.4921, Error: 0.1250,
# Iteration [513], Loss: 0.4150, Error: 0.1250,
# Iteration [514], Loss: 0.3768, Error: 0.1562,
# Iteration [515], Loss: 0.6280, Error: 0.1875,
# Iteration [516], Loss: 0.8872, Error: 0.2812,
# Iteration [517], Loss: 0.6882, Error: 0.2344,
# Iteration [518], Loss: 0.8129, Error: 0.2500,
# Iteration [519], Loss: 0.6609, Error: 0.1875,
# Iteration [520], Loss: 0.5930, Error: 0.0938,
# Iteration [521], Loss: 0.5337, Error: 0.1875,
# Iteration [522], Loss: 0.6943, Error: 0.1875,
# Iteration [523], Loss: 0.5863, Error: 0.1562,
# Iteration [524], Loss: 0.7857, Error: 0.2188,
# Iteration [525], Loss: 0.5775, Error: 0.1562,
# Iteration [526], Loss: 0.7606, Error: 0.2500,
# Iteration [527], Loss: 0.5116, Error: 0.1250,
# Iteration [528], Loss: 0.6324, Error: 0.2031,
# Iteration [529], Loss: 0.6158, Error: 0.2188,
# Iteration [530], Loss: 0.5452, Error: 0.1406,
# Iteration [531], Loss: 0.6213, Error: 0.2031,
# Iteration [532], Loss: 0.6026, Error: 0.1875,
# Iteration [533], Loss: 0.6304, Error: 0.2031,
# Iteration [534], Loss: 0.8225, Error: 0.2812,
# Iteration [535], Loss: 0.6628, Error: 0.2031,
# Iteration [536], Loss: 0.4737, Error: 0.1406,
# Iteration [537], Loss: 0.5499, Error: 0.1562,
# Iteration [538], Loss: 0.8343, Error: 0.2344,
# Iteration [539], Loss: 0.9784, Error: 0.3281,
# Iteration [540], Loss: 0.5243, Error: 0.1406,
# Iteration [541], Loss: 0.6644, Error: 0.1719,
# Iteration [542], Loss: 0.5532, Error: 0.1719,
# Iteration [543], Loss: 0.5141, Error: 0.0938,
# Iteration [544], Loss: 0.5626, Error: 0.1875,
# Iteration [545], Loss: 0.7127, Error: 0.2344,
# Iteration [546], Loss: 0.4059, Error: 0.1094,
# Iteration [547], Loss: 0.7036, Error: 0.2344,
# Iteration [548], Loss: 0.5233, Error: 0.1406,
# Iteration [549], Loss: 0.6853, Error: 0.2031,
# Iteration [550], Loss: 0.6097, Error: 0.1875,
# Iteration [551], Loss: 0.4969, Error: 0.1250,
# Iteration [552], Loss: 0.5839, Error: 0.1719,
# Iteration [553], Loss: 0.6439, Error: 0.1562,
# Iteration [554], Loss: 0.5460, Error: 0.1719,
# Iteration [555], Loss: 0.6145, Error: 0.1562,
# Iteration [556], Loss: 0.6950, Error: 0.2188,
# Iteration [557], Loss: 0.3721, Error: 0.0625,
# Iteration [558], Loss: 0.5189, Error: 0.1562,
# Iteration [559], Loss: 0.7347, Error: 0.2500,
# Iteration [560], Loss: 0.7608, Error: 0.2500,
# Iteration [561], Loss: 0.5040, Error: 0.1406,
# Iteration [562], Loss: 0.6748, Error: 0.1875,
# Iteration [563], Loss: 0.8421, Error: 0.2656,
# Iteration [564], Loss: 0.6332, Error: 0.1875,
# Iteration [565], Loss: 0.5687, Error: 0.1562,
# Iteration [566], Loss: 0.5146, Error: 0.1094,
# Iteration [567], Loss: 0.6802, Error: 0.2031,
# Iteration [568], Loss: 0.7587, Error: 0.2188,
# Iteration [569], Loss: 0.7821, Error: 0.2500,
# Iteration [570], Loss: 0.7576, Error: 0.2500,
# Iteration [571], Loss: 0.6220, Error: 0.2031,
# Iteration [572], Loss: 0.4803, Error: 0.1250,
# Iteration [573], Loss: 0.6832, Error: 0.1875,
# Iteration [574], Loss: 0.7052, Error: 0.2031,
# Iteration [575], Loss: 0.3831, Error: 0.1406,
# Iteration [576], Loss: 0.7505, Error: 0.2344,
# Iteration [577], Loss: 0.5579, Error: 0.1875,
# Iteration [578], Loss: 0.6229, Error: 0.1562,
# Iteration [579], Loss: 0.5799, Error: 0.1719,
# Iteration [580], Loss: 0.4330, Error: 0.1094,
# Iteration [581], Loss: 0.6255, Error: 0.2031,
# Iteration [582], Loss: 0.6684, Error: 0.2031,
# Iteration [583], Loss: 0.5459, Error: 0.1406,
# Iteration [584], Loss: 0.6152, Error: 0.2188,
# Iteration [585], Loss: 0.6531, Error: 0.2031,
# Iteration [586], Loss: 0.7204, Error: 0.1875,
# Iteration [587], Loss: 0.3378, Error: 0.0938,
# Iteration [588], Loss: 0.5579, Error: 0.1562,
# Iteration [589], Loss: 0.6107, Error: 0.1562,
# Iteration [590], Loss: 0.4764, Error: 0.1719,
# Iteration [591], Loss: 0.4655, Error: 0.1875,
# Iteration [592], Loss: 0.6681, Error: 0.1719,
# Iteration [593], Loss: 0.5782, Error: 0.1562,
# Iteration [594], Loss: 0.4820, Error: 0.1406,
# Iteration [595], Loss: 0.4336, Error: 0.1094,
# Iteration [596], Loss: 0.6436, Error: 0.2188,
# Iteration [597], Loss: 0.6810, Error: 0.2031,
# Iteration [598], Loss: 0.6169, Error: 0.1875,
# Iteration [599], Loss: 0.6048, Error: 0.1719,
# Iteration [600], Loss: 0.5925, Error: 0.1875,
# Iteration [601], Loss: 0.7888, Error: 0.2344,
# Iteration [602], Loss: 0.6131, Error: 0.1875,
# Iteration [603], Loss: 0.7152, Error: 0.2031,
# Iteration [604], Loss: 0.5686, Error: 0.1562,
# Iteration [605], Loss: 0.6853, Error: 0.2188,
# Iteration [606], Loss: 0.6985, Error: 0.2188,
# Iteration [607], Loss: 0.7324, Error: 0.2344,
# Iteration [608], Loss: 0.6561, Error: 0.1875,
# Iteration [609], Loss: 0.6198, Error: 0.1562,
# Iteration [610], Loss: 0.5926, Error: 0.1875,
# Iteration [611], Loss: 0.6704, Error: 0.1719,
# Iteration [612], Loss: 0.5406, Error: 0.1719,
# Iteration [613], Loss: 0.6462, Error: 0.2031,
# Iteration [614], Loss: 0.4070, Error: 0.1250,
# Iteration [615], Loss: 0.4938, Error: 0.1562,
# Iteration [616], Loss: 0.5858, Error: 0.1406,
# Iteration [617], Loss: 0.7304, Error: 0.2656,
# Iteration [618], Loss: 0.5684, Error: 0.1250,
# Iteration [619], Loss: 0.4734, Error: 0.1406,
# Iteration [620], Loss: 0.5202, Error: 0.1406,
# Iteration [621], Loss: 0.7293, Error: 0.2031,
# Iteration [622], Loss: 0.6491, Error: 0.2188,
# Iteration [623], Loss: 0.6851, Error: 0.2344,
# Iteration [624], Loss: 0.7175, Error: 0.2031,
# Iteration [625], Loss: 0.4806, Error: 0.1406,
# Iteration [626], Loss: 0.5540, Error: 0.1406,
# Iteration [627], Loss: 0.5968, Error: 0.1562,
# Iteration [628], Loss: 0.8900, Error: 0.3125,
# Iteration [629], Loss: 0.7113, Error: 0.2656,
# Iteration [630], Loss: 0.6127, Error: 0.1875,
# Iteration [631], Loss: 0.4847, Error: 0.0938,
# Iteration [632], Loss: 0.7573, Error: 0.2500,
# Iteration [633], Loss: 0.5057, Error: 0.1250,
# Iteration [634], Loss: 0.5087, Error: 0.1562,
# Iteration [635], Loss: 0.3700, Error: 0.0938,
# Iteration [636], Loss: 0.7098, Error: 0.2344,
# Iteration [637], Loss: 0.4897, Error: 0.1250,
# Iteration [638], Loss: 0.5833, Error: 0.1250,
# Iteration [639], Loss: 0.4888, Error: 0.1562,
# Iteration [640], Loss: 0.6375, Error: 0.2188,
# Iteration [641], Loss: 0.4536, Error: 0.1094,
# Iteration [642], Loss: 0.6010, Error: 0.2031,
# Iteration [643], Loss: 0.7355, Error: 0.2188,
# Iteration [644], Loss: 0.5609, Error: 0.1562,
# Iteration [645], Loss: 0.5596, Error: 0.1562,
# Iteration [646], Loss: 0.7132, Error: 0.2344,
# Iteration [647], Loss: 0.4442, Error: 0.1250,
# Iteration [648], Loss: 0.7841, Error: 0.2656,
# Iteration [649], Loss: 0.7896, Error: 0.2344,
# Iteration [650], Loss: 0.4434, Error: 0.1406,
# Iteration [651], Loss: 0.5718, Error: 0.2031,
# Iteration [652], Loss: 0.6758, Error: 0.2031,
# Iteration [653], Loss: 0.4716, Error: 0.1250,
# Iteration [654], Loss: 0.8036, Error: 0.2188,
# Iteration [655], Loss: 0.5424, Error: 0.1406,
# Iteration [656], Loss: 0.4904, Error: 0.1562,
# Iteration [657], Loss: 0.5184, Error: 0.1719,
# Iteration [658], Loss: 0.6476, Error: 0.2188,
# Iteration [659], Loss: 0.7693, Error: 0.2344,
# Iteration [660], Loss: 0.4946, Error: 0.0938,
# Iteration [661], Loss: 0.5333, Error: 0.1562,
# Iteration [662], Loss: 0.5632, Error: 0.1719,
# Iteration [663], Loss: 0.7235, Error: 0.2500,
# Iteration [664], Loss: 0.5557, Error: 0.1719,
# Iteration [665], Loss: 0.5797, Error: 0.2188,
# Iteration [666], Loss: 0.5021, Error: 0.1094,
# Iteration [667], Loss: 0.6199, Error: 0.1562,
# Iteration [668], Loss: 0.4561, Error: 0.1250,
# Iteration [669], Loss: 0.6027, Error: 0.1875,
# Iteration [670], Loss: 0.6795, Error: 0.2344,
# Iteration [671], Loss: 0.6225, Error: 0.1719,
# Iteration [672], Loss: 0.5074, Error: 0.1875,
# Iteration [673], Loss: 0.7382, Error: 0.2500,
# Iteration [674], Loss: 0.6427, Error: 0.2188,
# Iteration [675], Loss: 0.5862, Error: 0.2344,
# Iteration [676], Loss: 0.6020, Error: 0.1719,
# Iteration [677], Loss: 0.5469, Error: 0.1406,
# Iteration [678], Loss: 0.7228, Error: 0.2031,
# Iteration [679], Loss: 0.4692, Error: 0.1250,
# Iteration [680], Loss: 0.7705, Error: 0.2656,
# Iteration [681], Loss: 0.7472, Error: 0.2344,
# Iteration [682], Loss: 0.7005, Error: 0.2344,
# Iteration [683], Loss: 0.5112, Error: 0.1562,
# Iteration [684], Loss: 0.4675, Error: 0.1562,
# Iteration [685], Loss: 0.7335, Error: 0.2344,
# Iteration [686], Loss: 0.8306, Error: 0.2656,
# Iteration [687], Loss: 0.7337, Error: 0.2188,
# Iteration [688], Loss: 0.5736, Error: 0.1875,
# Iteration [689], Loss: 0.6947, Error: 0.2500,
# Iteration [690], Loss: 0.6519, Error: 0.2188,
# Iteration [691], Loss: 0.5306, Error: 0.1562,
# Iteration [692], Loss: 0.5498, Error: 0.1406,
# Iteration [693], Loss: 0.6434, Error: 0.2188,
# Iteration [694], Loss: 0.6907, Error: 0.1719,
# Iteration [695], Loss: 0.5529, Error: 0.1406,
# Iteration [696], Loss: 0.5981, Error: 0.2344,
# Iteration [697], Loss: 0.5646, Error: 0.2031,
# Iteration [698], Loss: 0.7313, Error: 0.2188,
# Iteration [699], Loss: 0.6691, Error: 0.2031,
# Iteration [700], Loss: 0.4675, Error: 0.1562,
# Iteration [701], Loss: 0.6363, Error: 0.1719,
# Iteration [702], Loss: 0.4557, Error: 0.1250,
# Iteration [703], Loss: 0.4349, Error: 0.1406,
# Iteration [704], Loss: 0.5607, Error: 0.1719,
# Iteration [705], Loss: 0.6793, Error: 0.2031,
# Iteration [706], Loss: 0.4657, Error: 0.0938,
# Iteration [707], Loss: 0.6545, Error: 0.1875,
# Iteration [708], Loss: 0.5187, Error: 0.1406,
# Iteration [709], Loss: 0.5088, Error: 0.1250,
# Iteration [710], Loss: 0.6054, Error: 0.1875,
# Iteration [711], Loss: 0.6743, Error: 0.2188,
# Iteration [712], Loss: 0.5617, Error: 0.1875,
# Iteration [713], Loss: 0.5202, Error: 0.1562,
# Iteration [714], Loss: 0.4212, Error: 0.1562,
# Iteration [715], Loss: 0.6914, Error: 0.2344,
# Iteration [716], Loss: 0.4284, Error: 0.1562,
# Iteration [717], Loss: 0.5509, Error: 0.1406,
# Iteration [718], Loss: 0.8724, Error: 0.2969,
# Iteration [719], Loss: 0.5380, Error: 0.1875,
# Iteration [720], Loss: 0.7902, Error: 0.2500,
# Iteration [721], Loss: 0.6579, Error: 0.2188,
# Iteration [722], Loss: 0.5388, Error: 0.1719,
# Iteration [723], Loss: 0.6666, Error: 0.2344,
# Iteration [724], Loss: 0.4557, Error: 0.1250,
# Iteration [725], Loss: 0.5097, Error: 0.1406,
# Iteration [726], Loss: 0.6458, Error: 0.2031,
# Iteration [727], Loss: 0.8618, Error: 0.3125,
# Iteration [728], Loss: 0.6356, Error: 0.1719,
# Iteration [729], Loss: 0.7090, Error: 0.2344,
# Iteration [730], Loss: 0.5989, Error: 0.1562,
# Iteration [731], Loss: 0.5964, Error: 0.1406,
# Iteration [732], Loss: 0.4955, Error: 0.1406,
# Iteration [733], Loss: 0.6974, Error: 0.2031,
# Iteration [734], Loss: 0.6784, Error: 0.2031,
# Iteration [735], Loss: 0.6732, Error: 0.2031,
# Iteration [736], Loss: 0.4535, Error: 0.1094,
# Iteration [737], Loss: 0.6260, Error: 0.1875,
# Iteration [738], Loss: 0.8633, Error: 0.2656,
# Iteration [739], Loss: 0.5649, Error: 0.1875,
# Iteration [740], Loss: 0.6421, Error: 0.2344,
# Iteration [741], Loss: 0.6115, Error: 0.1875,
# Iteration [742], Loss: 0.4166, Error: 0.0781,
# Iteration [743], Loss: 0.5116, Error: 0.1250,
# Iteration [744], Loss: 0.6053, Error: 0.1719,
# Iteration [745], Loss: 0.5187, Error: 0.1875,
# Iteration [746], Loss: 0.3735, Error: 0.0938,
# Iteration [747], Loss: 0.6224, Error: 0.1719,
# Iteration [748], Loss: 0.3891, Error: 0.1250,
# Iteration [749], Loss: 0.4600, Error: 0.1094,
# Iteration [750], Loss: 0.6728, Error: 0.1719,
# Iteration [751], Loss: 0.4603, Error: 0.0938,
# Iteration [752], Loss: 0.5207, Error: 0.1094,
# Iteration [753], Loss: 0.3964, Error: 0.0781,
# Iteration [754], Loss: 0.4719, Error: 0.1406,
# Iteration [755], Loss: 0.4587, Error: 0.1250,
# Iteration [756], Loss: 0.3642, Error: 0.0938,
# Iteration [757], Loss: 0.4497, Error: 0.1094,
# Iteration [758], Loss: 0.5799, Error: 0.1250,
# Iteration [759], Loss: 0.4262, Error: 0.0938,
# Iteration [760], Loss: 0.5022, Error: 0.1562,
# Iteration [761], Loss: 0.4272, Error: 0.0938,
# Iteration [762], Loss: 0.3911, Error: 0.1250,
# Iteration [763], Loss: 0.4256, Error: 0.0625,
# Iteration [764], Loss: 0.4981, Error: 0.1094,
# Iteration [765], Loss: 0.5553, Error: 0.1250,
# Iteration [766], Loss: 0.4034, Error: 0.0938,
# Iteration [767], Loss: 0.6448, Error: 0.2188,
# Iteration [768], Loss: 0.3764, Error: 0.1250,
# Iteration [769], Loss: 0.4228, Error: 0.1094,
# Iteration [770], Loss: 0.4475, Error: 0.1406,
# Iteration [771], Loss: 0.3548, Error: 0.1250,
# Iteration [772], Loss: 0.4344, Error: 0.0625,
# Iteration [773], Loss: 0.4880, Error: 0.0938,
# Iteration [774], Loss: 0.5662, Error: 0.1562,
# Iteration [775], Loss: 0.4291, Error: 0.1250,
# Iteration [776], Loss: 0.6188, Error: 0.1719,
# Iteration [777], Loss: 0.3467, Error: 0.0625,
# Iteration [778], Loss: 0.4648, Error: 0.1719,
# Iteration [779], Loss: 0.4787, Error: 0.1406,
# Iteration [780], Loss: 0.4169, Error: 0.1094,
# Iteration [781], Loss: 0.4859, Error: 0.1094,
# Iteration [782], Loss: 0.3418, Error: 0.1094,
# Iteration [783], Loss: 0.4309, Error: 0.0938,
# Iteration [784], Loss: 0.6725, Error: 0.1875,
# Iteration [785], Loss: 0.3641, Error: 0.0469,
# Iteration [786], Loss: 0.4753, Error: 0.1094,
# Iteration [787], Loss: 0.3832, Error: 0.1406,
# Iteration [788], Loss: 0.4651, Error: 0.1250,
# Iteration [789], Loss: 0.3824, Error: 0.0781,
# Iteration [790], Loss: 0.3525, Error: 0.0938,
# Iteration [791], Loss: 0.5339, Error: 0.1562,
# Iteration [792], Loss: 0.4210, Error: 0.1406,
# Iteration [793], Loss: 0.1975, Error: 0.0000,
# Iteration [794], Loss: 0.3191, Error: 0.0625,
# Iteration [795], Loss: 0.2753, Error: 0.0625,
# Iteration [796], Loss: 0.4443, Error: 0.1094,
# Iteration [797], Loss: 0.6016, Error: 0.1406,
# Iteration [798], Loss: 0.4981, Error: 0.1406,
# Iteration [799], Loss: 0.3120, Error: 0.0781,
# Iteration [800], Loss: 0.4908, Error: 0.1719,
# Iteration [801], Loss: 0.3896, Error: 0.0938,
# Iteration [802], Loss: 0.2869, Error: 0.0781,
# Iteration [803], Loss: 0.5702, Error: 0.2031,
# Iteration [804], Loss: 0.3938, Error: 0.0938,
# Iteration [805], Loss: 0.5574, Error: 0.1562,
# Iteration [806], Loss: 0.3863, Error: 0.1250,
# Iteration [807], Loss: 0.4518, Error: 0.1094,
# Iteration [808], Loss: 0.3925, Error: 0.0938,
# Iteration [809], Loss: 0.3770, Error: 0.0781,
# Iteration [810], Loss: 0.3788, Error: 0.1094,
# Iteration [811], Loss: 0.5238, Error: 0.1562,
# Iteration [812], Loss: 0.5618, Error: 0.1094,
# Iteration [813], Loss: 0.5076, Error: 0.1719,
# Iteration [814], Loss: 0.4278, Error: 0.1094,
# Iteration [815], Loss: 0.5339, Error: 0.1094,
# Iteration [816], Loss: 0.4466, Error: 0.1562,
# Iteration [817], Loss: 0.3125, Error: 0.0625,
# Iteration [818], Loss: 0.3689, Error: 0.0469,
# Iteration [819], Loss: 0.3815, Error: 0.0781,
# Iteration [820], Loss: 0.4114, Error: 0.1094,
# Iteration [821], Loss: 0.4313, Error: 0.1875,
# Iteration [822], Loss: 0.3553, Error: 0.0938,
# Iteration [823], Loss: 0.3468, Error: 0.0938,
# Iteration [824], Loss: 0.5585, Error: 0.1719,
# Iteration [825], Loss: 0.5057, Error: 0.1562,
# Iteration [826], Loss: 0.3973, Error: 0.1250,
# Iteration [827], Loss: 0.4500, Error: 0.1406,
# Iteration [828], Loss: 0.4122, Error: 0.1250,
# Iteration [829], Loss: 0.4730, Error: 0.1406,
# Iteration [830], Loss: 0.3422, Error: 0.1094,
# Iteration [831], Loss: 0.2474, Error: 0.0469,
# Iteration [832], Loss: 0.3568, Error: 0.0938,
# Iteration [833], Loss: 0.2989, Error: 0.0469,
# Iteration [834], Loss: 0.2030, Error: 0.0156,
# Iteration [835], Loss: 0.4218, Error: 0.1250,
# Iteration [836], Loss: 0.4413, Error: 0.1406,
# Iteration [837], Loss: 0.3985, Error: 0.1094,
# Iteration [838], Loss: 0.2380, Error: 0.0312,
# Iteration [839], Loss: 0.4301, Error: 0.0938,
# Iteration [840], Loss: 0.5188, Error: 0.1250,
# Iteration [841], Loss: 0.4187, Error: 0.1094,
# Iteration [842], Loss: 0.5362, Error: 0.1719,
# Iteration [843], Loss: 0.3899, Error: 0.1094,
# Iteration [844], Loss: 0.4227, Error: 0.1250,
# Iteration [845], Loss: 0.3046, Error: 0.0781,
# Iteration [846], Loss: 0.6098, Error: 0.2031,
# Iteration [847], Loss: 0.4906, Error: 0.1250,
# Iteration [848], Loss: 0.4139, Error: 0.1406,
# Iteration [849], Loss: 0.4402, Error: 0.1094,
# Iteration [850], Loss: 0.4442, Error: 0.1250,
# Iteration [851], Loss: 0.3594, Error: 0.0938,
# Iteration [852], Loss: 0.4254, Error: 0.0625,
# Iteration [853], Loss: 0.4483, Error: 0.1094,
# Iteration [854], Loss: 0.4378, Error: 0.1094,
# Iteration [855], Loss: 0.4752, Error: 0.1250,
# Iteration [856], Loss: 0.3126, Error: 0.0625,
# Iteration [857], Loss: 0.6254, Error: 0.2031,
# Iteration [858], Loss: 0.3952, Error: 0.0938,
# Iteration [859], Loss: 0.2870, Error: 0.0625,
# Iteration [860], Loss: 0.4564, Error: 0.1094,
# Iteration [861], Loss: 0.3779, Error: 0.0938,
# Iteration [862], Loss: 0.6575, Error: 0.1875,
# Iteration [863], Loss: 0.5393, Error: 0.1406,
# Iteration [864], Loss: 0.2051, Error: 0.0469,
# Iteration [865], Loss: 0.5613, Error: 0.1406,
# Iteration [866], Loss: 0.5934, Error: 0.1406,
# Iteration [867], Loss: 0.3768, Error: 0.0938,
# Iteration [868], Loss: 0.6196, Error: 0.1719,
# Iteration [869], Loss: 0.4480, Error: 0.1562,
# Iteration [870], Loss: 0.4158, Error: 0.1406,
# Iteration [871], Loss: 0.3625, Error: 0.0781,
# Iteration [872], Loss: 0.4631, Error: 0.0938,
# Iteration [873], Loss: 0.4101, Error: 0.1406,
# Iteration [874], Loss: 0.3412, Error: 0.0625,
# Iteration [875], Loss: 0.4755, Error: 0.1406,
# Iteration [876], Loss: 0.2216, Error: 0.0469,
# Iteration [877], Loss: 0.5320, Error: 0.1562,
# Iteration [878], Loss: 0.2674, Error: 0.0625,
# Iteration [879], Loss: 0.5084, Error: 0.1250,
# Iteration [880], Loss: 0.4242, Error: 0.0781,
# Iteration [881], Loss: 0.4174, Error: 0.1094,
# Iteration [882], Loss: 0.4367, Error: 0.1094,
# Iteration [883], Loss: 0.4040, Error: 0.1250,
# Iteration [884], Loss: 0.4412, Error: 0.0938,
# Iteration [885], Loss: 0.3341, Error: 0.0781,
# Iteration [886], Loss: 0.3849, Error: 0.1250,
# Iteration [887], Loss: 0.3148, Error: 0.0938,
# Iteration [888], Loss: 0.5456, Error: 0.1562,
# Iteration [889], Loss: 0.2569, Error: 0.0625,
# Iteration [890], Loss: 0.4182, Error: 0.0938,
# Iteration [891], Loss: 0.4771, Error: 0.1562,
# Iteration [892], Loss: 0.4617, Error: 0.0938,
# Iteration [893], Loss: 0.4479, Error: 0.1406,
# Iteration [894], Loss: 0.3341, Error: 0.0625,
# Iteration [895], Loss: 0.3402, Error: 0.0938,
# Iteration [896], Loss: 0.3176, Error: 0.1094,
# Iteration [897], Loss: 0.3964, Error: 0.0781,
# Iteration [898], Loss: 0.3452, Error: 0.0781,
# Iteration [899], Loss: 0.5555, Error: 0.1562,
# Iteration [900], Loss: 0.3829, Error: 0.1406,
# Iteration [901], Loss: 0.2288, Error: 0.0781,
# Iteration [902], Loss: 0.3236, Error: 0.0781,
# Iteration [903], Loss: 0.4214, Error: 0.1094,
# Iteration [904], Loss: 0.4345, Error: 0.0938,
# Iteration [905], Loss: 0.3177, Error: 0.0625,
# Iteration [906], Loss: 0.3247, Error: 0.0938,
# Iteration [907], Loss: 0.3017, Error: 0.0938,
# Iteration [908], Loss: 0.4847, Error: 0.1719,
# Iteration [909], Loss: 0.3891, Error: 0.0938,
# Iteration [910], Loss: 0.2390, Error: 0.0781,
# Iteration [911], Loss: 0.3209, Error: 0.0938,
# Iteration [912], Loss: 0.4483, Error: 0.1406,
# Iteration [913], Loss: 0.2727, Error: 0.0781,
# Iteration [914], Loss: 0.4355, Error: 0.1719,
# Iteration [915], Loss: 0.5377, Error: 0.1562,
# Iteration [916], Loss: 0.3664, Error: 0.0469,
# Iteration [917], Loss: 0.2838, Error: 0.0625,
# Iteration [918], Loss: 0.4233, Error: 0.0938,
# Iteration [919], Loss: 0.4769, Error: 0.1250,
# Iteration [920], Loss: 0.2963, Error: 0.0781,
# Iteration [921], Loss: 0.4867, Error: 0.1250,
# Iteration [922], Loss: 0.3730, Error: 0.1094,
# Iteration [923], Loss: 0.6295, Error: 0.1719,
# Iteration [924], Loss: 0.5392, Error: 0.1250,
# Iteration [925], Loss: 0.3176, Error: 0.0938,
# Iteration [926], Loss: 0.6391, Error: 0.1250,
# Iteration [927], Loss: 0.4227, Error: 0.1406,
# Iteration [928], Loss: 0.4886, Error: 0.1719,
# Iteration [929], Loss: 0.5464, Error: 0.1250,
# Iteration [930], Loss: 0.3331, Error: 0.0938,
# Iteration [931], Loss: 0.4162, Error: 0.1406,
# Iteration [932], Loss: 0.4274, Error: 0.1094,
# Iteration [933], Loss: 0.4510, Error: 0.1250,
# Iteration [934], Loss: 0.2104, Error: 0.0156,
# Iteration [935], Loss: 0.4162, Error: 0.1094,
# Iteration [936], Loss: 0.4324, Error: 0.1406,
# Iteration [937], Loss: 0.4547, Error: 0.1042,
# Iteration [938], Loss: 0.5260, Error: 0.2031,
# Iteration [939], Loss: 0.3309, Error: 0.0781,
# Iteration [940], Loss: 0.3206, Error: 0.0781,
# Iteration [941], Loss: 0.2969, Error: 0.0781,
# Iteration [942], Loss: 0.1372, Error: 0.0156,
# Iteration [943], Loss: 0.2920, Error: 0.0781,
# Iteration [944], Loss: 0.6332, Error: 0.1719,
# Iteration [945], Loss: 0.4096, Error: 0.0938,
# Iteration [946], Loss: 0.3715, Error: 0.1250,
# Iteration [947], Loss: 0.4068, Error: 0.1250,
# Iteration [948], Loss: 0.3775, Error: 0.1406,
# Iteration [949], Loss: 0.2805, Error: 0.0625,
# Iteration [950], Loss: 0.4580, Error: 0.1719,
# Iteration [951], Loss: 0.3203, Error: 0.1094,
# Iteration [952], Loss: 0.4368, Error: 0.0781,
# Iteration [953], Loss: 0.3872, Error: 0.0938,
# Iteration [954], Loss: 0.5070, Error: 0.1719,
# Iteration [955], Loss: 0.3344, Error: 0.0781,
# Iteration [956], Loss: 0.4589, Error: 0.1250,
# Iteration [957], Loss: 0.3773, Error: 0.1094,
# Iteration [958], Loss: 0.2244, Error: 0.0625,
# Iteration [959], Loss: 0.4161, Error: 0.1406,
# Iteration [960], Loss: 0.2180, Error: 0.0469,
# Iteration [961], Loss: 0.4394, Error: 0.1406,
# Iteration [962], Loss: 0.4101, Error: 0.1094,
# Iteration [963], Loss: 0.4540, Error: 0.1094,
# Iteration [964], Loss: 0.4321, Error: 0.1094,
# Iteration [965], Loss: 0.5321, Error: 0.1406,
# Iteration [966], Loss: 0.5278, Error: 0.1875,
# Iteration [967], Loss: 0.3044, Error: 0.0938,
# Iteration [968], Loss: 0.3227, Error: 0.0938,
# Iteration [969], Loss: 0.3581, Error: 0.1250,
# Iteration [970], Loss: 0.3598, Error: 0.0938,
# Iteration [971], Loss: 0.4154, Error: 0.1094,
# Iteration [972], Loss: 0.4180, Error: 0.1406,
# Iteration [973], Loss: 0.3778, Error: 0.0781,
# Iteration [974], Loss: 0.4638, Error: 0.1406,
# Iteration [975], Loss: 0.3488, Error: 0.0938,
# Iteration [976], Loss: 0.4715, Error: 0.1406,
# Iteration [977], Loss: 0.4253, Error: 0.1250,
# Iteration [978], Loss: 0.3118, Error: 0.1094,
# Iteration [979], Loss: 0.2685, Error: 0.0938,
# Iteration [980], Loss: 0.3560, Error: 0.1094,
# Iteration [981], Loss: 0.5916, Error: 0.1719,
# Iteration [982], Loss: 0.3190, Error: 0.0625,
# Iteration [983], Loss: 0.2638, Error: 0.0312,
# Iteration [984], Loss: 0.2189, Error: 0.0469,
# Iteration [985], Loss: 0.6944, Error: 0.2344,
# Iteration [986], Loss: 0.3854, Error: 0.1406,
# Iteration [987], Loss: 0.2787, Error: 0.0469,
# Iteration [988], Loss: 0.4458, Error: 0.1719,
# Iteration [989], Loss: 0.1827, Error: 0.0312,
# Iteration [990], Loss: 0.3312, Error: 0.1094,
# Iteration [991], Loss: 0.4262, Error: 0.1406,
# Iteration [992], Loss: 0.3835, Error: 0.1250,
# Iteration [993], Loss: 0.3938, Error: 0.1562,
# Iteration [994], Loss: 0.3785, Error: 0.0938,
# Iteration [995], Loss: 0.2317, Error: 0.0312,
# Iteration [996], Loss: 0.3785, Error: 0.0781,
# Iteration [997], Loss: 0.2344, Error: 0.0312,
# Iteration [998], Loss: 0.3455, Error: 0.0469,
# Iteration [999], Loss: 0.2713, Error: 0.0625,
# Iteration [1000], Loss: 0.3052, Error: 0.0625,
# Iteration [1001], Loss: 0.3815, Error: 0.0781,
# Iteration [1002], Loss: 0.3272, Error: 0.0781,
# Iteration [1003], Loss: 0.2050, Error: 0.0312,
# Iteration [1004], Loss: 0.4029, Error: 0.0938,
# Iteration [1005], Loss: 0.4944, Error: 0.1406,
# Iteration [1006], Loss: 0.5366, Error: 0.2031,
# Iteration [1007], Loss: 0.2295, Error: 0.0625,
# Iteration [1008], Loss: 0.2004, Error: 0.0625,
# Iteration [1009], Loss: 0.2862, Error: 0.0625,
# Iteration [1010], Loss: 0.3727, Error: 0.1094,
# Iteration [1011], Loss: 0.3252, Error: 0.0938,
# Iteration [1012], Loss: 0.3186, Error: 0.0781,
# Iteration [1013], Loss: 0.4207, Error: 0.1250,
# Iteration [1014], Loss: 0.2270, Error: 0.0469,
# Iteration [1015], Loss: 0.2847, Error: 0.0781,
# Iteration [1016], Loss: 0.4171, Error: 0.1250,
# Iteration [1017], Loss: 0.4024, Error: 0.1250,
# Iteration [1018], Loss: 0.2839, Error: 0.1094,
# Iteration [1019], Loss: 0.3784, Error: 0.0781,
# Iteration [1020], Loss: 0.4918, Error: 0.1562,
# Iteration [1021], Loss: 0.4066, Error: 0.0781,
# Iteration [1022], Loss: 0.2830, Error: 0.0625,
# ...
# Iteration [2717], Loss: 0.3258, Error: 0.0781,
# Iteration [2718], Loss: 0.4393, Error: 0.1094,
# Iteration [2719], Loss: 0.3669, Error: 0.1250,
# Iteration [2720], Loss: 0.2738, Error: 0.0625,
# Iteration [2721], Loss: 0.4706, Error: 0.1250,
# Iteration [2722], Loss: 0.2944, Error: 0.1406,
# Iteration [2723], Loss: 0.2770, Error: 0.0469,
# Iteration [2724], Loss: 0.2494, Error: 0.0781,
# Iteration [2725], Loss: 0.5238, Error: 0.1250,
# Iteration [2726], Loss: 0.3227, Error: 0.0781,
# Iteration [2727], Loss: 0.3645, Error: 0.1094,
# Iteration [2728], Loss: 0.2870, Error: 0.0781,
# Iteration [2729], Loss: 0.2385, Error: 0.0312,
# Iteration [2730], Loss: 0.3672, Error: 0.0781,
# Iteration [2731], Loss: 0.2338, Error: 0.0781,
# Iteration [2732], Loss: 0.4455, Error: 0.1406,
# Iteration [2733], Loss: 0.4664, Error: 0.1875,
# Iteration [2734], Loss: 0.1792, Error: 0.0312,
# Iteration [2735], Loss: 0.2076, Error: 0.0312,
# Iteration [2736], Loss: 0.3732, Error: 0.1094,
# Iteration [2737], Loss: 0.2718, Error: 0.0625,
# Iteration [2738], Loss: 0.2354, Error: 0.0781,
# Iteration [2739], Loss: 0.3465, Error: 0.1094,
# Iteration [2740], Loss: 0.3393, Error: 0.1250,
# Iteration [2741], Loss: 0.5489, Error: 0.0938,
# Iteration [2742], Loss: 0.4449, Error: 0.1562,
# Iteration [2743], Loss: 0.2590, Error: 0.0625,
# Iteration [2744], Loss: 0.3569, Error: 0.0781,
# Iteration [2745], Loss: 0.2083, Error: 0.0312,
# Iteration [2746], Loss: 0.3386, Error: 0.1250,
# Iteration [2747], Loss: 0.2466, Error: 0.0781,
# Iteration [2748], Loss: 0.3622, Error: 0.0938,
# Iteration [2749], Loss: 0.4072, Error: 0.1250,
# Iteration [2750], Loss: 0.2352, Error: 0.0938,
# Iteration [2751], Loss: 0.5082, Error: 0.1406,
# Iteration [2752], Loss: 0.4947, Error: 0.1250,
# Iteration [2753], Loss: 0.3019, Error: 0.0781,
# Iteration [2754], Loss: 0.3134, Error: 0.1250,
# Iteration [2755], Loss: 0.4537, Error: 0.1562,
# Iteration [2756], Loss: 0.1428, Error: 0.0312,
# Iteration [2757], Loss: 0.4108, Error: 0.0938,
# Iteration [2758], Loss: 0.1741, Error: 0.0469,
# Iteration [2759], Loss: 0.4743, Error: 0.0938,
# Iteration [2760], Loss: 0.6246, Error: 0.1250,
# Iteration [2761], Loss: 0.3050, Error: 0.0938,
# Iteration [2762], Loss: 0.3968, Error: 0.1094,
# Iteration [2763], Loss: 0.4153, Error: 0.1094,
# Iteration [2764], Loss: 0.2419, Error: 0.0625,
# Iteration [2765], Loss: 0.1588, Error: 0.0312,
# Iteration [2766], Loss: 0.2655, Error: 0.0312,
# Iteration [2767], Loss: 0.3608, Error: 0.0625,
# Iteration [2768], Loss: 0.2657, Error: 0.0938,
# Iteration [2769], Loss: 0.1789, Error: 0.0312,
# Iteration [2770], Loss: 0.2185, Error: 0.0781,
# Iteration [2771], Loss: 0.4474, Error: 0.1094,
# Iteration [2772], Loss: 0.3864, Error: 0.1406,
# Iteration [2773], Loss: 0.2875, Error: 0.1250,
# Iteration [2774], Loss: 0.1169, Error: 0.0156,
# Iteration [2775], Loss: 0.2978, Error: 0.0938,
# Iteration [2776], Loss: 0.3037, Error: 0.1094,
# Iteration [2777], Loss: 0.1311, Error: 0.0156,
# Iteration [2778], Loss: 0.2121, Error: 0.0469,
# Iteration [2779], Loss: 0.3812, Error: 0.1250,
# Iteration [2780], Loss: 0.5653, Error: 0.1406,
# Iteration [2781], Loss: 0.2052, Error: 0.0469,
# Iteration [2782], Loss: 0.2552, Error: 0.0625,
# Iteration [2783], Loss: 0.2243, Error: 0.0938,
# Iteration [2784], Loss: 0.2594, Error: 0.0625,
# Iteration [2785], Loss: 0.2591, Error: 0.0938,
# Iteration [2786], Loss: 0.2260, Error: 0.0625,
# Iteration [2787], Loss: 0.4294, Error: 0.1094,
# Iteration [2788], Loss: 0.3876, Error: 0.1406,
# Iteration [2789], Loss: 0.3896, Error: 0.0938,
# Iteration [2790], Loss: 0.4670, Error: 0.0938,
# Iteration [2791], Loss: 0.2421, Error: 0.0625,
# Iteration [2792], Loss: 0.4525, Error: 0.0938,
# Iteration [2793], Loss: 0.3551, Error: 0.1094,
# Iteration [2794], Loss: 0.3000, Error: 0.0781,
# Iteration [2795], Loss: 0.2415, Error: 0.0469,
# Iteration [2796], Loss: 0.2769, Error: 0.0625,
# Iteration [2797], Loss: 0.2974, Error: 0.0938,
# Iteration [2798], Loss: 0.3247, Error: 0.0938,
# Iteration [2799], Loss: 0.0913, Error: 0.0000,
# Iteration [2800], Loss: 0.2711, Error: 0.0469,
# Iteration [2801], Loss: 0.5380, Error: 0.2188,
# Iteration [2802], Loss: 0.2153, Error: 0.0781,
# Iteration [2803], Loss: 0.3134, Error: 0.0938,
# Iteration [2804], Loss: 0.2926, Error: 0.1094,
# Iteration [2805], Loss: 0.2121, Error: 0.0625,
# Iteration [2806], Loss: 0.2113, Error: 0.0781,
# Iteration [2807], Loss: 0.2354, Error: 0.0625,
# Iteration [2808], Loss: 0.3279, Error: 0.0938,
# Iteration [2809], Loss: 0.3358, Error: 0.0938,
# Iteration [2810], Loss: 0.4213, Error: 0.0938,
# Iteration [2811], Loss: 0.3232, Error: 0.0781,
# Iteration [2812], Loss: 0.2952, Error: 0.1094,
# Iteration [2813], Loss: 0.3416, Error: 0.0833,
# Iteration [2814], Loss: 0.3674, Error: 0.0781,
# Iteration [2815], Loss: 0.1929, Error: 0.0469,
# Iteration [2816], Loss: 0.2714, Error: 0.0781,
# Iteration [2817], Loss: 0.2963, Error: 0.0781,
# Iteration [2818], Loss: 0.2912, Error: 0.0312,
# Iteration [2819], Loss: 0.2994, Error: 0.0625,
# Iteration [2820], Loss: 0.3510, Error: 0.1094,
# Iteration [2821], Loss: 0.3573, Error: 0.1094,
# Iteration [2822], Loss: 0.2923, Error: 0.0938,
# Iteration [2823], Loss: 0.3002, Error: 0.1094,
# Iteration [2824], Loss: 0.3671, Error: 0.0938,
# Iteration [2825], Loss: 0.3795, Error: 0.0938,
# Iteration [2826], Loss: 0.4399, Error: 0.1094,
# Iteration [2827], Loss: 0.2335, Error: 0.0625,
# Iteration [2828], Loss: 0.2595, Error: 0.1094,
# Iteration [2829], Loss: 0.2495, Error: 0.0781,
# Iteration [2830], Loss: 0.2705, Error: 0.0469,
# Iteration [2831], Loss: 0.2751, Error: 0.0625,
# Iteration [2832], Loss: 0.2817, Error: 0.0625,
# Iteration [2833], Loss: 0.4515, Error: 0.1406,
# Iteration [2834], Loss: 0.3231, Error: 0.0625,
# Iteration [2835], Loss: 0.3780, Error: 0.1094,
# Iteration [2836], Loss: 0.2577, Error: 0.0938,
# Iteration [2837], Loss: 0.4120, Error: 0.1094,
# Iteration [2838], Loss: 0.2088, Error: 0.0312,
# Iteration [2839], Loss: 0.2230, Error: 0.0938,
# Iteration [2840], Loss: 0.3078, Error: 0.0781,
# Iteration [2841], Loss: 0.2255, Error: 0.0625,
# Iteration [2842], Loss: 0.2860, Error: 0.0938,
# Iteration [2843], Loss: 0.2152, Error: 0.0938,
# Iteration [2844], Loss: 0.1731, Error: 0.0312,
# Iteration [2845], Loss: 0.2453, Error: 0.0625,
# Iteration [2846], Loss: 0.1673, Error: 0.0469,
# Iteration [2847], Loss: 0.2647, Error: 0.0781,
# Iteration [2848], Loss: 0.2743, Error: 0.0938,
# Iteration [2849], Loss: 0.2824, Error: 0.1094,
# Iteration [2850], Loss: 0.4412, Error: 0.0938,
# Iteration [2851], Loss: 0.2377, Error: 0.0938,
# Iteration [2852], Loss: 0.3352, Error: 0.0938,
# Iteration [2853], Loss: 0.5081, Error: 0.1250,
# Iteration [2854], Loss: 0.4934, Error: 0.1719,
# Iteration [2855], Loss: 0.4808, Error: 0.1406,
# Iteration [2856], Loss: 0.1554, Error: 0.0625,
# Iteration [2857], Loss: 0.2432, Error: 0.0625,
# Iteration [2858], Loss: 0.4015, Error: 0.1406,
# Iteration [2859], Loss: 0.3824, Error: 0.1250,
# Iteration [2860], Loss: 0.2526, Error: 0.1094,
# Iteration [2861], Loss: 0.2215, Error: 0.0469,
# Iteration [2862], Loss: 0.3020, Error: 0.1250,
# Iteration [2863], Loss: 0.4412, Error: 0.1406,
# Iteration [2864], Loss: 0.3813, Error: 0.1250,
# Iteration [2865], Loss: 0.4033, Error: 0.0938,
# Iteration [2866], Loss: 0.2439, Error: 0.0625,
# Iteration [2867], Loss: 0.3984, Error: 0.1250,
# Iteration [2868], Loss: 0.2784, Error: 0.1094,
# Iteration [2869], Loss: 0.3982, Error: 0.1094,
# Iteration [2870], Loss: 0.2211, Error: 0.0625,
# Iteration [2871], Loss: 0.1805, Error: 0.0625,
# Iteration [2872], Loss: 0.2568, Error: 0.0938,
# Iteration [2873], Loss: 0.3914, Error: 0.0781,
# Iteration [2874], Loss: 0.1747, Error: 0.0312,
# Iteration [2875], Loss: 0.3737, Error: 0.0938,
# Iteration [2876], Loss: 0.2892, Error: 0.0781,
# Iteration [2877], Loss: 0.3675, Error: 0.0938,
# Iteration [2878], Loss: 0.3006, Error: 0.0625,
# Iteration [2879], Loss: 0.3807, Error: 0.1562,
# Iteration [2880], Loss: 0.4416, Error: 0.1875,
# Iteration [2881], Loss: 0.3981, Error: 0.1250,
# Iteration [2882], Loss: 0.3032, Error: 0.0938,
# Iteration [2883], Loss: 0.3810, Error: 0.1094,
# Iteration [2884], Loss: 0.3323, Error: 0.0938,
# Iteration [2885], Loss: 0.2540, Error: 0.0781,
# Iteration [2886], Loss: 0.2973, Error: 0.0781,
# Iteration [2887], Loss: 0.2743, Error: 0.0781,
# Iteration [2888], Loss: 0.3287, Error: 0.0938,
# Iteration [2889], Loss: 0.4182, Error: 0.1094,
# Iteration [2890], Loss: 0.2311, Error: 0.0781,
# Iteration [2891], Loss: 0.0894, Error: 0.0156,
# Iteration [2892], Loss: 0.1775, Error: 0.0469,
# Iteration [2893], Loss: 0.2028, Error: 0.0625,
# Iteration [2894], Loss: 0.2419, Error: 0.0469,
# Iteration [2895], Loss: 0.6604, Error: 0.1406,
# Iteration [2896], Loss: 0.4504, Error: 0.1250,
# Iteration [2897], Loss: 0.3420, Error: 0.0469,
# Iteration [2898], Loss: 0.2330, Error: 0.0469,
# Iteration [2899], Loss: 0.3980, Error: 0.0938,
# Iteration [2900], Loss: 0.3152, Error: 0.0625,
# Iteration [2901], Loss: 0.3344, Error: 0.1250,
# Iteration [2902], Loss: 0.2531, Error: 0.0781,
# Iteration [2903], Loss: 0.3312, Error: 0.0625,
# Iteration [2904], Loss: 0.2624, Error: 0.0938,
# Iteration [2905], Loss: 0.1898, Error: 0.0469,
# Iteration [2906], Loss: 0.4048, Error: 0.0938,
# Iteration [2907], Loss: 0.2915, Error: 0.0781,
# Iteration [2908], Loss: 0.2938, Error: 0.0938,
# Iteration [2909], Loss: 0.3953, Error: 0.0781,
# Iteration [2910], Loss: 0.3124, Error: 0.0781,
# Iteration [2911], Loss: 0.2047, Error: 0.0781,
# Iteration [2912], Loss: 0.2573, Error: 0.0625,
# Iteration [2913], Loss: 0.2643, Error: 0.1250,
# Iteration [2914], Loss: 0.3820, Error: 0.1406,
# Iteration [2915], Loss: 0.1921, Error: 0.0156,
# Iteration [2916], Loss: 0.2254, Error: 0.0625,
# Iteration [2917], Loss: 0.2456, Error: 0.0938,
# Iteration [2918], Loss: 0.3200, Error: 0.0938,
# Iteration [2919], Loss: 0.3227, Error: 0.0625,
# Iteration [2920], Loss: 0.2213, Error: 0.0469,
# Iteration [2921], Loss: 0.2835, Error: 0.0781,
# Iteration [2922], Loss: 0.1648, Error: 0.0312,
# Iteration [2923], Loss: 0.2046, Error: 0.0625,
# Iteration [2924], Loss: 0.3588, Error: 0.0469,
# Iteration [2925], Loss: 0.2510, Error: 0.0625,
# Iteration [2926], Loss: 0.2480, Error: 0.0781,
# Iteration [2927], Loss: 0.4005, Error: 0.0781,
# Iteration [2928], Loss: 0.2119, Error: 0.0469,
# Iteration [2929], Loss: 0.4033, Error: 0.1250,
# Iteration [2930], Loss: 0.2354, Error: 0.0469,
# Iteration [2931], Loss: 0.2048, Error: 0.0312,
# Iteration [2932], Loss: 0.2809, Error: 0.0781,
# Iteration [2933], Loss: 0.2061, Error: 0.0625,
# Iteration [2934], Loss: 0.2076, Error: 0.0469,
# Iteration [2935], Loss: 0.1929, Error: 0.0469,
# Iteration [2936], Loss: 0.2810, Error: 0.0469,
# Iteration [2937], Loss: 0.2711, Error: 0.0781,
# Iteration [2938], Loss: 0.4416, Error: 0.0938,
# Iteration [2939], Loss: 0.2718, Error: 0.0781,
# Iteration [2940], Loss: 0.2441, Error: 0.0781,
# Iteration [2941], Loss: 0.2268, Error: 0.0469,
# Iteration [2942], Loss: 0.1910, Error: 0.0625,
# Iteration [2943], Loss: 0.2413, Error: 0.0781,
# Iteration [2944], Loss: 0.2561, Error: 0.0938,
# Iteration [2945], Loss: 0.2193, Error: 0.0469,
# Iteration [2946], Loss: 0.2145, Error: 0.0625,
# Iteration [2947], Loss: 0.2228, Error: 0.0625,
# Iteration [2948], Loss: 0.2609, Error: 0.0469,
# Iteration [2949], Loss: 0.2255, Error: 0.0781,
# Iteration [2950], Loss: 0.4597, Error: 0.1406,
# Iteration [2951], Loss: 0.1400, Error: 0.0469,
# Iteration [2952], Loss: 0.2805, Error: 0.0625,
# Iteration [2953], Loss: 0.4431, Error: 0.1562,
# Iteration [2954], Loss: 0.2244, Error: 0.0469,
# Iteration [2955], Loss: 0.3994, Error: 0.0938,
# Iteration [2956], Loss: 0.3097, Error: 0.0781,
# Iteration [2957], Loss: 0.2739, Error: 0.0938,
# Iteration [2958], Loss: 0.2502, Error: 0.0625,
# Iteration [2959], Loss: 0.5146, Error: 0.1250,
# Iteration [2960], Loss: 0.2027, Error: 0.0469,
# Iteration [2961], Loss: 0.3241, Error: 0.0938,
# Iteration [2962], Loss: 0.1252, Error: 0.0312,
# Iteration [2963], Loss: 0.3885, Error: 0.0625,
# Iteration [2964], Loss: 0.3299, Error: 0.0938,
# Iteration [2965], Loss: 0.3793, Error: 0.1250,
# Iteration [2966], Loss: 0.3041, Error: 0.0312,
# Iteration [2967], Loss: 0.3074, Error: 0.0938,
# Iteration [2968], Loss: 0.4076, Error: 0.2031,
# Iteration [2969], Loss: 0.2650, Error: 0.0781,
# Iteration [2970], Loss: 0.1558, Error: 0.0312,
# Iteration [2971], Loss: 0.2622, Error: 0.0938,
# Iteration [2972], Loss: 0.2618, Error: 0.1094,
# Iteration [2973], Loss: 0.3375, Error: 0.1094,
# Iteration [2974], Loss: 0.2352, Error: 0.0312,
# Iteration [2975], Loss: 0.4854, Error: 0.1094,
# Iteration [2976], Loss: 0.2132, Error: 0.0938,
# Iteration [2977], Loss: 0.3308, Error: 0.1094,
# Iteration [2978], Loss: 0.1859, Error: 0.0625,
# Iteration [2979], Loss: 0.1677, Error: 0.0469,
# Iteration [2980], Loss: 0.2791, Error: 0.0938,
# Iteration [2981], Loss: 0.1291, Error: 0.0312,
# Iteration [2982], Loss: 0.3340, Error: 0.0625,
# Iteration [2983], Loss: 0.3623, Error: 0.1094,
# Iteration [2984], Loss: 0.2393, Error: 0.0469,
# Iteration [2985], Loss: 0.3192, Error: 0.0938,
# Iteration [2986], Loss: 0.3703, Error: 0.1094,
# Iteration [2987], Loss: 0.2683, Error: 0.0781,
# Iteration [2988], Loss: 0.4047, Error: 0.1406,
# Iteration [2989], Loss: 0.3408, Error: 0.0625,
# Iteration [2990], Loss: 0.2391, Error: 0.0469,
# Iteration [2991], Loss: 0.2918, Error: 0.0781,
# Iteration [2992], Loss: 0.5585, Error: 0.1875,
# Iteration [2993], Loss: 0.3726, Error: 0.1250,
# Iteration [2994], Loss: 0.2571, Error: 0.0625,
# Iteration [2995], Loss: 0.3282, Error: 0.0938,
# Iteration [2996], Loss: 0.2780, Error: 0.0469,
# Iteration [2997], Loss: 0.2042, Error: 0.0625,
# Iteration [2998], Loss: 0.5216, Error: 0.1250,
# Iteration [2999], Loss: 0.2825, Error: 0.0625,
# Iteration [3000], Loss: 0.2245, Error: 0.0625,
# Iteration [3001], Loss: 0.2525, Error: 0.0625,
# Iteration [3002], Loss: 0.4321, Error: 0.1094,
# Iteration [3003], Loss: 0.2655, Error: 0.0312,
# Iteration [3004], Loss: 0.2333, Error: 0.0781,
# Iteration [3005], Loss: 0.3379, Error: 0.0938,
# Iteration [3006], Loss: 0.3041, Error: 0.1094,
# Iteration [3007], Loss: 0.2103, Error: 0.0625,
# Iteration [3008], Loss: 0.3768, Error: 0.1094,
# Iteration [3009], Loss: 0.2053, Error: 0.0469,
# Iteration [3010], Loss: 0.3161, Error: 0.0469,
# Iteration [3011], Loss: 0.3553, Error: 0.0938,
# Iteration [3012], Loss: 0.1476, Error: 0.0312,
# Iteration [3013], Loss: 0.4802, Error: 0.1406,
# Iteration [3014], Loss: 0.2085, Error: 0.0312,
# Iteration [3015], Loss: 0.1646, Error: 0.0312,
# Iteration [3016], Loss: 0.2539, Error: 0.0625,
# Iteration [3017], Loss: 0.3025, Error: 0.0625,
# Iteration [3018], Loss: 0.3774, Error: 0.1406,
# Iteration [3019], Loss: 0.2814, Error: 0.0938,
# Iteration [3020], Loss: 0.2128, Error: 0.0625,
# Iteration [3021], Loss: 0.3203, Error: 0.0625,
# Iteration [3022], Loss: 0.4200, Error: 0.1250,
# Iteration [3023], Loss: 0.2558, Error: 0.0625,
# Iteration [3024], Loss: 0.2105, Error: 0.0781,
# Iteration [3025], Loss: 0.4487, Error: 0.0938,
# Iteration [3026], Loss: 0.1158, Error: 0.0156,
# Iteration [3027], Loss: 0.2450, Error: 0.0781,
# Iteration [3028], Loss: 0.2409, Error: 0.0781,
# Iteration [3029], Loss: 0.2462, Error: 0.0781,
# Iteration [3030], Loss: 0.2304, Error: 0.0938,
# Iteration [3031], Loss: 0.1057, Error: 0.0156,
# Iteration [3032], Loss: 0.5556, Error: 0.1094,
# Iteration [3033], Loss: 0.2800, Error: 0.1094,
# Iteration [3034], Loss: 0.2902, Error: 0.1094,
# Iteration [3035], Loss: 0.2061, Error: 0.0625,
# Iteration [3036], Loss: 0.4190, Error: 0.1094,
# Iteration [3037], Loss: 0.5023, Error: 0.1719,
# Iteration [3038], Loss: 0.2955, Error: 0.1250,
# Iteration [3039], Loss: 0.3278, Error: 0.0625,
# Iteration [3040], Loss: 0.5312, Error: 0.1250,
# Iteration [3041], Loss: 0.1726, Error: 0.0625,
# Iteration [3042], Loss: 0.1820, Error: 0.0312,
# Iteration [3043], Loss: 0.3169, Error: 0.0938,
# Iteration [3044], Loss: 0.2317, Error: 0.0312,
# Iteration [3045], Loss: 0.3111, Error: 0.1562,
# Iteration [3046], Loss: 0.3074, Error: 0.1094,
# Iteration [3047], Loss: 0.3573, Error: 0.0938,
# Iteration [3048], Loss: 0.2314, Error: 0.0625,
# Iteration [3049], Loss: 0.2649, Error: 0.0781,

# %%
###############################
##### TEST YOUR CODE HERE #####
###############################

def test_train_function_runs(train_loss_list, train_error_list, val_loss_list, val_error_list):
    
    assert len(train_loss_list) > 0, "Train loss list is empty!"
    assert len(train_error_list) > 0, "Train error list is empty!"
    assert len(val_loss_list) > 0, "Validation loss list is empty!"
    assert len(val_error_list) > 0, "Validation error list is empty!"
    
test_train_function_runs(train_loss_list, train_error_list, val_loss_list, val_error_list)
print("The test_train_function is running correctly")
# Out:
# The test_train_function is running correctly

# %%
###############################
##### TEST YOUR CODE HERE #####
###############################
def test_training_loss_decrease(train_loss_list):
    
    assert train_loss_list[0] > train_loss_list[-1], (
        f"Expected training loss to decrease, but got initial loss {train_loss_list[0]} and final loss {train_loss_list[-1]}"
    )
test_training_loss_decrease(train_loss_list)
print("The training and validation loss decreases with learning")
# Out:
# The training and validation loss decreases with learning

# %%
###############################
##### TEST YOUR CODE HERE #####
###############################
def test_validation_loss_non_negative(net, val_dataloader):

    avg_val_loss, _ = validate_pytorch_NN(net, val_dataloader)
    
    assert avg_val_loss >= 0, f"Expected non-negative validation loss, but got {avg_val_loss}"
    
test_validation_loss_non_negative(net, val_dataloader)
print("The Test validation loss is non-negative")
# Out:
# The Test validation loss is non-negative

# %%
def plot_losses(train_loss_list, val_loss_list, val_interval=1000):
    """
    Plot separate training and validation losses.

    train_loss_list: List of training losses
    val_loss_list: List of validation losses
    val_interval: Interval of iterations when validation is calculated
    """
    val_iters = [i for i in range(0, len(train_loss_list), val_interval)]

    # Plot Training Loss
    plt.figure(figsize=(8, 5))
    plt.plot(range(len(train_loss_list)), train_loss_list)
    plt.xlabel('Iterations')
    plt.ylabel('Training Loss')
    plt.title('Training Loss vs Iterations')
    plt.show()
    

    # Plot Validation Loss
    plt.figure(figsize=(8, 5))
    plt.plot(val_iters, val_loss_list, marker='o')
    plt.xlabel('Iterations')
    plt.ylabel('Validation Loss')
    plt.title('Validation Loss vs Iterations')
    plt.show()

# # Example usage (assuming you have train_loss_list and val_loss_list):
# train_loss_list, train_error_list, val_loss_list, val_error_list = train_pytorch_nn(net, train_dataloader, val_dataloader)

# Plot the losses
plot_losses(train_loss_list, val_loss_list, val_interval=1000)

# %% [markdown]
# ## Final Takeaways
# Congratulations on finishing up the assignment. Here are some final points:
#
# 1. The graph we plotted at the very end shows that the training loss and validation loss both decrease with iterations performed. This is the model learning itself.
#
# 2. We have not discussed many details about the neural network developed in this assignment. It is a simple linear single layer network used for learning purposes. However, how to construct a neural network to improve its performance is a whole topic in itself.
#
# 3. You may have noticed that we used 3050 iterations for training. We are performing the validation step after every 1000 iterations. To clearly show three steps of validation learning, we used a value slightly above 3000.
#
# 4. We generally train models 10 times more than what we did in this assignment. However, we have limited the iterations as a trade off for faster training.
